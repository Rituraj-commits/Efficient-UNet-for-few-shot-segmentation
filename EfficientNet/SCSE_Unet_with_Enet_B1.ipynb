# %%
# !nvidia-smi
# Out:
# Sat Jul 10 08:08:09 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading https://files.pythonhosted.org/packages/2e/a0/dd40b50aebf0028054b6b35062948da01123d7be38d08b6b1e5435df6363/efficientnet_pytorch-0.7.1.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=61e93e7180ff3dc0cc6ac05ce83123236288d1c1292fbdc9870ece958854d83a
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
# !git clone -b fsl https://Rituraj-commits:rd34%24%40%24%40@github.com/Rituraj-commits/Efficientnet-U-Net.Pytorch.git

# %%
cd /content/Efficientnet-U-Net.Pytorch/U-Net_with_Eff_Net
# Out:
# /content/Efficientnet-U-Net.Pytorch/U-Net_with_Eff_Net

# %%
# !unzip '/content/drive/MyDrive/FewShot.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: FewShot/fss1000/refrigerator/label/10.png
#   inflating: FewShot/fss1000/refrigerator/label/2.png
#   inflating: FewShot/fss1000/refrigerator/label/3.png
#   inflating: FewShot/fss1000/refrigerator/label/4.png
#   inflating: FewShot/fss1000/refrigerator/label/5.png
#   inflating: FewShot/fss1000/refrigerator/label/6.png
#   inflating: FewShot/fss1000/refrigerator/label/7.png
#   inflating: FewShot/fss1000/refrigerator/label/8.png
#   inflating: FewShot/fss1000/refrigerator/label/9.png
#    creating: FewShot/fss1000/relay_stick/
#    creating: FewShot/fss1000/relay_stick/image/
#   inflating: FewShot/fss1000/relay_stick/image/1.jpg
#   inflating: FewShot/fss1000/relay_stick/image/10.jpg
#   inflating: FewShot/fss1000/relay_stick/image/2.jpg
#   inflating: FewShot/fss1000/relay_stick/image/3.jpg
#   inflating: FewShot/fss1000/relay_stick/image/4.jpg
#   inflating: FewShot/fss1000/relay_stick/image/5.jpg
#   inflating: FewShot/fss1000/relay_stick/image/6.jpg
#   inflating: FewShot/fss1000/relay_stick/image/7.jpg
#   inflating: FewShot/fss1000/relay_stick/image/8.jpg
#   inflating: FewShot/fss1000/relay_stick/image/9.jpg
#    creating: FewShot/fss1000/relay_stick/label/
#   inflating: FewShot/fss1000/relay_stick/label/1.png
#   inflating: FewShot/fss1000/relay_stick/label/10.png
#   inflating: FewShot/fss1000/relay_stick/label/2.png
#   inflating: FewShot/fss1000/relay_stick/label/3.png
#   inflating: FewShot/fss1000/relay_stick/label/4.png
#   inflating: FewShot/fss1000/relay_stick/label/5.png
#   inflating: FewShot/fss1000/relay_stick/label/6.png
#   inflating: FewShot/fss1000/relay_stick/label/7.png
#   inflating: FewShot/fss1000/relay_stick/label/8.png
#   inflating: FewShot/fss1000/relay_stick/label/9.png
#    creating: FewShot/fss1000/remote_control/
#    creating: FewShot/fss1000/remote_control/image/
#   inflating: FewShot/fss1000/remote_control/image/1.jpg
#   inflating: FewShot/fss1000/remote_control/image/10.jpg
#   inflating: FewShot/fss1000/remote_control/image/2.jpg
#   inflating: FewShot/fss1000/remote_control/image/3.jpg
#   inflating: FewShot/fss1000/remote_control/image/4.jpg
#   inflating: FewShot/fss1000/remote_control/image/5.jpg
#   inflating: FewShot/fss1000/remote_control/image/6.jpg
#   inflating: FewShot/fss1000/remote_control/image/7.jpg
#   inflating: FewShot/fss1000/remote_control/image/8.jpg
#   inflating: FewShot/fss1000/remote_control/image/9.jpg
#    creating: FewShot/fss1000/remote_control/label/
#   inflating: FewShot/fss1000/remote_control/label/1.png
#   inflating: FewShot/fss1000/remote_control/label/10.png
#   inflating: FewShot/fss1000/remote_control/label/2.png
#   inflating: FewShot/fss1000/remote_control/label/3.png
#   inflating: FewShot/fss1000/remote_control/label/4.png
#   inflating: FewShot/fss1000/remote_control/label/5.png
#   inflating: FewShot/fss1000/remote_control/label/6.png
#   inflating: FewShot/fss1000/remote_control/label/7.png
#   inflating: FewShot/fss1000/remote_control/label/8.png
#   inflating: FewShot/fss1000/remote_control/label/9.png
#    creating: FewShot/fss1000/revolver/
#    creating: FewShot/fss1000/revolver/image/
#   inflating: FewShot/fss1000/revolver/image/1.jpg
#   inflating: FewShot/fss1000/revolver/image/10.jpg
#   inflating: FewShot/fss1000/revolver/image/2.jpg
#   inflating: FewShot/fss1000/revolver/image/3.jpg
#   inflating: FewShot/fss1000/revolver/image/4.jpg
#   inflating: FewShot/fss1000/revolver/image/5.jpg
#   inflating: FewShot/fss1000/revolver/image/6.jpg
#   inflating: FewShot/fss1000/revolver/image/7.jpg
#   inflating: FewShot/fss1000/revolver/image/8.jpg
#   inflating: FewShot/fss1000/revolver/image/9.jpg
#    creating: FewShot/fss1000/revolver/label/
#   inflating: FewShot/fss1000/revolver/label/1.png
#   inflating: FewShot/fss1000/revolver/label/10.png
#   inflating: FewShot/fss1000/revolver/label/2.png
#   inflating: FewShot/fss1000/revolver/label/3.png
#   inflating: FewShot/fss1000/revolver/label/4.png
#   inflating: FewShot/fss1000/revolver/label/5.png
#   inflating: FewShot/fss1000/revolver/label/6.png
#   inflating: FewShot/fss1000/revolver/label/7.png
#   inflating: FewShot/fss1000/revolver/label/8.png
#   inflating: FewShot/fss1000/revolver/label/9.png
#    creating: FewShot/fss1000/rhinoceros/
#    creating: FewShot/fss1000/rhinoceros/image/
#   inflating: FewShot/fss1000/rhinoceros/image/1.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/10.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/2.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/3.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/4.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/5.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/6.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/7.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/8.jpg
#   inflating: FewShot/fss1000/rhinoceros/image/9.jpg
#    creating: FewShot/fss1000/rhinoceros/label/
#   inflating: FewShot/fss1000/rhinoceros/label/1.png
#   inflating: FewShot/fss1000/rhinoceros/label/10.png
#   inflating: FewShot/fss1000/rhinoceros/label/2.png
#   inflating: FewShot/fss1000/rhinoceros/label/3.png
#   inflating: FewShot/fss1000/rhinoceros/label/4.png
#   inflating: FewShot/fss1000/rhinoceros/label/5.png
#   inflating: FewShot/fss1000/rhinoceros/label/6.png
#   inflating: FewShot/fss1000/rhinoceros/label/7.png
#   inflating: FewShot/fss1000/rhinoceros/label/8.png
#   inflating: FewShot/fss1000/rhinoceros/label/9.png
#    creating: FewShot/fss1000/ringlet_butterfly/
#    creating: FewShot/fss1000/ringlet_butterfly/image/
#   inflating: FewShot/fss1000/ringlet_butterfly/image/1.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/10.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/2.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/3.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/4.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/5.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/6.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/7.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/8.jpg
#   inflating: FewShot/fss1000/ringlet_butterfly/image/9.jpg
#    creating: FewShot/fss1000/ringlet_butterfly/label/
#   inflating: FewShot/fss1000/ringlet_butterfly/label/1.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/10.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/2.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/3.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/4.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/5.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/6.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/7.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/8.png
#   inflating: FewShot/fss1000/ringlet_butterfly/label/9.png
#    creating: FewShot/fss1000/rock_beauty/
#    creating: FewShot/fss1000/rock_beauty/image/
#   inflating: FewShot/fss1000/rock_beauty/image/1.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/10.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/2.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/3.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/4.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/5.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/6.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/7.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/8.jpg
#   inflating: FewShot/fss1000/rock_beauty/image/9.jpg
#    creating: FewShot/fss1000/rock_beauty/label/
#   inflating: FewShot/fss1000/rock_beauty/label/1.png
#   inflating: FewShot/fss1000/rock_beauty/label/10.png
#   inflating: FewShot/fss1000/rock_beauty/label/2.png
#   inflating: FewShot/fss1000/rock_beauty/label/3.png
#   inflating: FewShot/fss1000/rock_beauty/label/4.png
#   inflating: FewShot/fss1000/rock_beauty/label/5.png
#   inflating: FewShot/fss1000/rock_beauty/label/6.png
#   inflating: FewShot/fss1000/rock_beauty/label/7.png
#   inflating: FewShot/fss1000/rock_beauty/label/8.png
#   inflating: FewShot/fss1000/rock_beauty/label/9.png
#    creating: FewShot/fss1000/rock_snake/
#    creating: FewShot/fss1000/rock_snake/image/
#   inflating: FewShot/fss1000/rock_snake/image/1.jpg
#   inflating: FewShot/fss1000/rock_snake/image/10.jpg
#   inflating: FewShot/fss1000/rock_snake/image/2.jpg
#   inflating: FewShot/fss1000/rock_snake/image/3.jpg
#   inflating: FewShot/fss1000/rock_snake/image/4.jpg
#   inflating: FewShot/fss1000/rock_snake/image/5.jpg
#   inflating: FewShot/fss1000/rock_snake/image/6.jpg
#   inflating: FewShot/fss1000/rock_snake/image/7.jpg
#   inflating: FewShot/fss1000/rock_snake/image/8.jpg
#   inflating: FewShot/fss1000/rock_snake/image/9.jpg
#    creating: FewShot/fss1000/rock_snake/label/
#   inflating: FewShot/fss1000/rock_snake/label/1.png
#   inflating: FewShot/fss1000/rock_snake/label/10.png
#   inflating: FewShot/fss1000/rock_snake/label/2.png
#   inflating: FewShot/fss1000/rock_snake/label/3.png
#   inflating: FewShot/fss1000/rock_snake/label/4.png
#   inflating: FewShot/fss1000/rock_snake/label/5.png
#   inflating: FewShot/fss1000/rock_snake/label/6.png
#   inflating: FewShot/fss1000/rock_snake/label/7.png
#   inflating: FewShot/fss1000/rock_snake/label/8.png
#   inflating: FewShot/fss1000/rock_snake/label/9.png
#    creating: FewShot/fss1000/rocket/
#    creating: FewShot/fss1000/rocket/image/
#   inflating: FewShot/fss1000/rocket/image/1.jpg
#   inflating: FewShot/fss1000/rocket/image/10.jpg
#   inflating: FewShot/fss1000/rocket/image/2.jpg
#   inflating: FewShot/fss1000/rocket/image/3.jpg
#   inflating: FewShot/fss1000/rocket/image/4.jpg
#   inflating: FewShot/fss1000/rocket/image/5.jpg
#   inflating: FewShot/fss1000/rocket/image/6.jpg
#   inflating: FewShot/fss1000/rocket/image/7.jpg
#   inflating: FewShot/fss1000/rocket/image/8.jpg
#   inflating: FewShot/fss1000/rocket/image/9.jpg
#    creating: FewShot/fss1000/rocket/label/
#   inflating: FewShot/fss1000/rocket/label/1.png
#   inflating: FewShot/fss1000/rocket/label/10.png
#   inflating: FewShot/fss1000/rocket/label/2.png
#   inflating: FewShot/fss1000/rocket/label/3.png
#   inflating: FewShot/fss1000/rocket/label/4.png
#   inflating: FewShot/fss1000/rocket/label/5.png
#   inflating: FewShot/fss1000/rocket/label/6.png
#   inflating: FewShot/fss1000/rocket/label/7.png
#   inflating: FewShot/fss1000/rocket/label/8.png
#   inflating: FewShot/fss1000/rocket/label/9.png
#    creating: FewShot/fss1000/roller_coaster/
#    creating: FewShot/fss1000/roller_coaster/image/
#   inflating: FewShot/fss1000/roller_coaster/image/1.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/10.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/2.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/3.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/4.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/5.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/6.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/7.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/8.jpg
#   inflating: FewShot/fss1000/roller_coaster/image/9.jpg
#    creating: FewShot/fss1000/roller_coaster/label/
#   inflating: FewShot/fss1000/roller_coaster/label/1.png
#   inflating: FewShot/fss1000/roller_coaster/label/10.png
#   inflating: FewShot/fss1000/roller_coaster/label/2.png
#   inflating: FewShot/fss1000/roller_coaster/label/3.png
#   inflating: FewShot/fss1000/roller_coaster/label/4.png
#   inflating: FewShot/fss1000/roller_coaster/label/5.png
#   inflating: FewShot/fss1000/roller_coaster/label/6.png
#   inflating: FewShot/fss1000/roller_coaster/label/7.png
#   inflating: FewShot/fss1000/roller_coaster/label/8.png
#   inflating: FewShot/fss1000/roller_coaster/label/9.png
#    creating: FewShot/fss1000/roller_skate/
#    creating: FewShot/fss1000/roller_skate/image/
#   inflating: FewShot/fss1000/roller_skate/image/1.jpg
#   inflating: FewShot/fss1000/roller_skate/image/10.jpg
#   inflating: FewShot/fss1000/roller_skate/image/2.jpg
#   inflating: FewShot/fss1000/roller_skate/image/3.jpg
#   inflating: FewShot/fss1000/roller_skate/image/4.jpg
#   inflating: FewShot/fss1000/roller_skate/image/5.jpg
#   inflating: FewShot/fss1000/roller_skate/image/6.jpg
#   inflating: FewShot/fss1000/roller_skate/image/7.jpg
#   inflating: FewShot/fss1000/roller_skate/image/8.jpg
#   inflating: FewShot/fss1000/roller_skate/image/9.jpg
#    creating: FewShot/fss1000/roller_skate/label/
#   inflating: FewShot/fss1000/roller_skate/label/1.png
#   inflating: FewShot/fss1000/roller_skate/label/10.png
#   inflating: FewShot/fss1000/roller_skate/label/2.png
#   inflating: FewShot/fss1000/roller_skate/label/3.png
#   inflating: FewShot/fss1000/roller_skate/label/4.png
#   inflating: FewShot/fss1000/roller_skate/label/5.png
#   inflating: FewShot/fss1000/roller_skate/label/6.png
#   inflating: FewShot/fss1000/roller_skate/label/7.png
#   inflating: FewShot/fss1000/roller_skate/label/8.png
#   inflating: FewShot/fss1000/roller_skate/label/9.png
#    creating: FewShot/fss1000/rose/
#    creating: FewShot/fss1000/rose/image/
#   inflating: FewShot/fss1000/rose/image/1.jpg
#   inflating: FewShot/fss1000/rose/image/10.jpg
#   inflating: FewShot/fss1000/rose/image/2.jpg
#   inflating: FewShot/fss1000/rose/image/3.jpg
#   inflating: FewShot/fss1000/rose/image/4.jpg
#   inflating: FewShot/fss1000/rose/image/5.jpg
#   inflating: FewShot/fss1000/rose/image/6.jpg
#   inflating: FewShot/fss1000/rose/image/7.jpg
#   inflating: FewShot/fss1000/rose/image/8.jpg
#   inflating: FewShot/fss1000/rose/image/9.jpg
#    creating: FewShot/fss1000/rose/label/
#   inflating: FewShot/fss1000/rose/label/1.png
#   inflating: FewShot/fss1000/rose/label/10.png
#   inflating: FewShot/fss1000/rose/label/2.png
#   inflating: FewShot/fss1000/rose/label/3.png
#   inflating: FewShot/fss1000/rose/label/4.png
#   inflating: FewShot/fss1000/rose/label/5.png
#   inflating: FewShot/fss1000/rose/label/6.png
#   inflating: FewShot/fss1000/rose/label/7.png
#   inflating: FewShot/fss1000/rose/label/8.png
#   inflating: FewShot/fss1000/rose/label/9.png
#    creating: FewShot/fss1000/rosehip/
#    creating: FewShot/fss1000/rosehip/image/
#   inflating: FewShot/fss1000/rosehip/image/1.jpg
#   inflating: FewShot/fss1000/rosehip/image/10.jpg
#   inflating: FewShot/fss1000/rosehip/image/2.jpg
#   inflating: FewShot/fss1000/rosehip/image/3.jpg
#   inflating: FewShot/fss1000/rosehip/image/4.jpg
#   inflating: FewShot/fss1000/rosehip/image/5.jpg
#   inflating: FewShot/fss1000/rosehip/image/6.jpg
#   inflating: FewShot/fss1000/rosehip/image/7.jpg
#   inflating: FewShot/fss1000/rosehip/image/8.jpg
#   inflating: FewShot/fss1000/rosehip/image/9.jpg
#    creating: FewShot/fss1000/rosehip/label/
#   inflating: FewShot/fss1000/rosehip/label/1.png
#   inflating: FewShot/fss1000/rosehip/label/10.png
#   inflating: FewShot/fss1000/rosehip/label/2.png
#   inflating: FewShot/fss1000/rosehip/label/3.png
#   inflating: FewShot/fss1000/rosehip/label/4.png
#   inflating: FewShot/fss1000/rosehip/label/5.png
#   inflating: FewShot/fss1000/rosehip/label/6.png
#   inflating: FewShot/fss1000/rosehip/label/7.png
#   inflating: FewShot/fss1000/rosehip/label/8.png
#   inflating: FewShot/fss1000/rosehip/label/9.png
#    creating: FewShot/fss1000/ruddy_turnstone/
#    creating: FewShot/fss1000/ruddy_turnstone/image/
#   inflating: FewShot/fss1000/ruddy_turnstone/image/1.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/10.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/2.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/3.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/4.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/5.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/6.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/7.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/8.jpg
#   inflating: FewShot/fss1000/ruddy_turnstone/image/9.jpg
#    creating: FewShot/fss1000/ruddy_turnstone/label/
#   inflating: FewShot/fss1000/ruddy_turnstone/label/1.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/10.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/2.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/3.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/4.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/5.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/6.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/7.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/8.png
#   inflating: FewShot/fss1000/ruddy_turnstone/label/9.png
#    creating: FewShot/fss1000/ruffed_grouse/
#    creating: FewShot/fss1000/ruffed_grouse/image/
#   inflating: FewShot/fss1000/ruffed_grouse/image/1.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/10.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/2.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/3.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/4.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/5.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/6.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/7.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/8.jpg
#   inflating: FewShot/fss1000/ruffed_grouse/image/9.jpg
#    creating: FewShot/fss1000/ruffed_grouse/label/
#   inflating: FewShot/fss1000/ruffed_grouse/label/1.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/10.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/2.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/3.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/4.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/5.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/6.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/7.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/8.png
#   inflating: FewShot/fss1000/ruffed_grouse/label/9.png
#    creating: FewShot/fss1000/running_shoe/
#    creating: FewShot/fss1000/running_shoe/image/
#   inflating: FewShot/fss1000/running_shoe/image/1.jpg
#   inflating: FewShot/fss1000/running_shoe/image/10.jpg
#   inflating: FewShot/fss1000/running_shoe/image/2.jpg
#   inflating: FewShot/fss1000/running_shoe/image/3.jpg
#   inflating: FewShot/fss1000/running_shoe/image/4.jpg
#   inflating: FewShot/fss1000/running_shoe/image/5.jpg
#   inflating: FewShot/fss1000/running_shoe/image/6.jpg
#   inflating: FewShot/fss1000/running_shoe/image/7.jpg
#   inflating: FewShot/fss1000/running_shoe/image/8.jpg
#   inflating: FewShot/fss1000/running_shoe/image/9.jpg
#    creating: FewShot/fss1000/running_shoe/label/
#   inflating: FewShot/fss1000/running_shoe/label/1.png
#   inflating: FewShot/fss1000/running_shoe/label/10.png
#   inflating: FewShot/fss1000/running_shoe/label/2.png
#   inflating: FewShot/fss1000/running_shoe/label/3.png
#   inflating: FewShot/fss1000/running_shoe/label/4.png
#   inflating: FewShot/fss1000/running_shoe/label/5.png
#   inflating: FewShot/fss1000/running_shoe/label/6.png
#   inflating: FewShot/fss1000/running_shoe/label/7.png
#   inflating: FewShot/fss1000/running_shoe/label/8.png
#   inflating: FewShot/fss1000/running_shoe/label/9.png
#    creating: FewShot/fss1000/saltshaker/
#    creating: FewShot/fss1000/saltshaker/image/
#   inflating: FewShot/fss1000/saltshaker/image/1.jpg
#   inflating: FewShot/fss1000/saltshaker/image/10.jpg
#   inflating: FewShot/fss1000/saltshaker/image/2.jpg
#   inflating: FewShot/fss1000/saltshaker/image/3.jpg
#   inflating: FewShot/fss1000/saltshaker/image/4.jpg
#   inflating: FewShot/fss1000/saltshaker/image/5.jpg
#   inflating: FewShot/fss1000/saltshaker/image/6.jpg
#   inflating: FewShot/fss1000/saltshaker/image/7.jpg
#   inflating: FewShot/fss1000/saltshaker/image/8.jpg
#   inflating: FewShot/fss1000/saltshaker/image/9.jpg
#    creating: FewShot/fss1000/saltshaker/label/
#   inflating: FewShot/fss1000/saltshaker/label/1.png
#   inflating: FewShot/fss1000/saltshaker/label/10.png
#   inflating: FewShot/fss1000/saltshaker/label/2.png
#   inflating: FewShot/fss1000/saltshaker/label/3.png
#   inflating: FewShot/fss1000/saltshaker/label/4.png
#   inflating: FewShot/fss1000/saltshaker/label/5.png
#   inflating: FewShot/fss1000/saltshaker/label/6.png
#   inflating: FewShot/fss1000/saltshaker/label/7.png
#   inflating: FewShot/fss1000/saltshaker/label/8.png
#   inflating: FewShot/fss1000/saltshaker/label/9.png
#    creating: FewShot/fss1000/saluki/
#    creating: FewShot/fss1000/saluki/image/
#   inflating: FewShot/fss1000/saluki/image/1.jpg
#   inflating: FewShot/fss1000/saluki/image/10.jpg
#   inflating: FewShot/fss1000/saluki/image/2.jpg
#   inflating: FewShot/fss1000/saluki/image/3.jpg
#   inflating: FewShot/fss1000/saluki/image/4.jpg
#   inflating: FewShot/fss1000/saluki/image/5.jpg
#   inflating: FewShot/fss1000/saluki/image/6.jpg
#   inflating: FewShot/fss1000/saluki/image/7.jpg
#   inflating: FewShot/fss1000/saluki/image/8.jpg
#   inflating: FewShot/fss1000/saluki/image/9.jpg
#    creating: FewShot/fss1000/saluki/label/
#   inflating: FewShot/fss1000/saluki/label/1.png
#   inflating: FewShot/fss1000/saluki/label/10.png
#   inflating: FewShot/fss1000/saluki/label/2.png
#   inflating: FewShot/fss1000/saluki/label/3.png
#   inflating: FewShot/fss1000/saluki/label/4.png
#   inflating: FewShot/fss1000/saluki/label/5.png
#   inflating: FewShot/fss1000/saluki/label/6.png
#   inflating: FewShot/fss1000/saluki/label/7.png
#   inflating: FewShot/fss1000/saluki/label/8.png
#   inflating: FewShot/fss1000/saluki/label/9.png
#    creating: FewShot/fss1000/sandal/
#    creating: FewShot/fss1000/sandal/image/
#   inflating: FewShot/fss1000/sandal/image/1.jpg
#   inflating: FewShot/fss1000/sandal/image/10.jpg
#   inflating: FewShot/fss1000/sandal/image/2.jpg
#   inflating: FewShot/fss1000/sandal/image/3.jpg
#   inflating: FewShot/fss1000/sandal/image/4.jpg
#   inflating: FewShot/fss1000/sandal/image/5.jpg
#   inflating: FewShot/fss1000/sandal/image/6.jpg
#   inflating: FewShot/fss1000/sandal/image/7.jpg
#   inflating: FewShot/fss1000/sandal/image/8.jpg
#   inflating: FewShot/fss1000/sandal/image/9.jpg
#    creating: FewShot/fss1000/sandal/label/
#   inflating: FewShot/fss1000/sandal/label/1.png
#   inflating: FewShot/fss1000/sandal/label/10.png
#   inflating: FewShot/fss1000/sandal/label/2.png
#   inflating: FewShot/fss1000/sandal/label/3.png
#   inflating: FewShot/fss1000/sandal/label/4.png
#   inflating: FewShot/fss1000/sandal/label/5.png
#   inflating: FewShot/fss1000/sandal/label/6.png
#   inflating: FewShot/fss1000/sandal/label/7.png
#   inflating: FewShot/fss1000/sandal/label/8.png
#   inflating: FewShot/fss1000/sandal/label/9.png
#    creating: FewShot/fss1000/sandbar/
#    creating: FewShot/fss1000/sandbar/image/
#   inflating: FewShot/fss1000/sandbar/image/1.jpg
#   inflating: FewShot/fss1000/sandbar/image/10.jpg
#   inflating: FewShot/fss1000/sandbar/image/2.jpg
#   inflating: FewShot/fss1000/sandbar/image/3.jpg
#   inflating: FewShot/fss1000/sandbar/image/4.jpg
#   inflating: FewShot/fss1000/sandbar/image/5.jpg
#   inflating: FewShot/fss1000/sandbar/image/6.jpg
#   inflating: FewShot/fss1000/sandbar/image/7.jpg
#   inflating: FewShot/fss1000/sandbar/image/8.jpg
#   inflating: FewShot/fss1000/sandbar/image/9.jpg
#    creating: FewShot/fss1000/sandbar/label/
#   inflating: FewShot/fss1000/sandbar/label/1.png
#   inflating: FewShot/fss1000/sandbar/label/10.png
#   inflating: FewShot/fss1000/sandbar/label/2.png
#   inflating: FewShot/fss1000/sandbar/label/3.png
#   inflating: FewShot/fss1000/sandbar/label/4.png
#   inflating: FewShot/fss1000/sandbar/label/5.png
#   inflating: FewShot/fss1000/sandbar/label/6.png
#   inflating: FewShot/fss1000/sandbar/label/7.png
#   inflating: FewShot/fss1000/sandbar/label/8.png
#   inflating: FewShot/fss1000/sandbar/label/9.png
#    creating: FewShot/fss1000/sandwich/
#    creating: FewShot/fss1000/sandwich/image/
#   inflating: FewShot/fss1000/sandwich/image/1.jpg
#   inflating: FewShot/fss1000/sandwich/image/10.jpg
#   inflating: FewShot/fss1000/sandwich/image/2.jpg
#   inflating: FewShot/fss1000/sandwich/image/3.jpg
#   inflating: FewShot/fss1000/sandwich/image/4.jpg
#   inflating: FewShot/fss1000/sandwich/image/5.jpg
#   inflating: FewShot/fss1000/sandwich/image/6.jpg
#   inflating: FewShot/fss1000/sandwich/image/7.jpg
#   inflating: FewShot/fss1000/sandwich/image/8.jpg
#   inflating: FewShot/fss1000/sandwich/image/9.jpg
#    creating: FewShot/fss1000/sandwich/label/
#   inflating: FewShot/fss1000/sandwich/label/1.png
#   inflating: FewShot/fss1000/sandwich/label/10.png
#   inflating: FewShot/fss1000/sandwich/label/2.png
#   inflating: FewShot/fss1000/sandwich/label/3.png
#   inflating: FewShot/fss1000/sandwich/label/4.png
#   inflating: FewShot/fss1000/sandwich/label/5.png
#   inflating: FewShot/fss1000/sandwich/label/6.png
#   inflating: FewShot/fss1000/sandwich/label/7.png
#   inflating: FewShot/fss1000/sandwich/label/8.png
#   inflating: FewShot/fss1000/sandwich/label/9.png
#    creating: FewShot/fss1000/sandwich_cookies/
#    creating: FewShot/fss1000/sandwich_cookies/image/
#   inflating: FewShot/fss1000/sandwich_cookies/image/1.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/10.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/2.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/3.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/4.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/5.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/6.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/7.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/8.jpg
#   inflating: FewShot/fss1000/sandwich_cookies/image/9.jpg
#    creating: FewShot/fss1000/sandwich_cookies/label/
#   inflating: FewShot/fss1000/sandwich_cookies/label/1.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/10.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/2.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/3.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/4.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/5.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/6.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/7.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/8.png
#   inflating: FewShot/fss1000/sandwich_cookies/label/9.png
#    creating: FewShot/fss1000/sarong/
#    creating: FewShot/fss1000/sarong/image/
#   inflating: FewShot/fss1000/sarong/image/1.jpg
#   inflating: FewShot/fss1000/sarong/image/10.jpg
#   inflating: FewShot/fss1000/sarong/image/2.jpg
#   inflating: FewShot/fss1000/sarong/image/3.jpg
#   inflating: FewShot/fss1000/sarong/image/4.jpg
#   inflating: FewShot/fss1000/sarong/image/5.jpg
#   inflating: FewShot/fss1000/sarong/image/6.jpg
#   inflating: FewShot/fss1000/sarong/image/7.jpg
#   inflating: FewShot/fss1000/sarong/image/8.jpg
#   inflating: FewShot/fss1000/sarong/image/9.jpg
#    creating: FewShot/fss1000/sarong/label/
#   inflating: FewShot/fss1000/sarong/label/1.png
#   inflating: FewShot/fss1000/sarong/label/10.png
#   inflating: FewShot/fss1000/sarong/label/2.png
#   inflating: FewShot/fss1000/sarong/label/3.png
#   inflating: FewShot/fss1000/sarong/label/4.png
#   inflating: FewShot/fss1000/sarong/label/5.png
#   inflating: FewShot/fss1000/sarong/label/6.png
#   inflating: FewShot/fss1000/sarong/label/7.png
#   inflating: FewShot/fss1000/sarong/label/8.png
#   inflating: FewShot/fss1000/sarong/label/9.png
#    creating: FewShot/fss1000/saxophone/
#    creating: FewShot/fss1000/saxophone/image/
#   inflating: FewShot/fss1000/saxophone/image/1.jpg
#   inflating: FewShot/fss1000/saxophone/image/10.jpg
#   inflating: FewShot/fss1000/saxophone/image/2.jpg
#   inflating: FewShot/fss1000/saxophone/image/3.jpg
#   inflating: FewShot/fss1000/saxophone/image/4.jpg
#   inflating: FewShot/fss1000/saxophone/image/5.jpg
#   inflating: FewShot/fss1000/saxophone/image/6.jpg
#   inflating: FewShot/fss1000/saxophone/image/7.jpg
#   inflating: FewShot/fss1000/saxophone/image/8.jpg
#   inflating: FewShot/fss1000/saxophone/image/9.jpg
#    creating: FewShot/fss1000/saxophone/label/
#   inflating: FewShot/fss1000/saxophone/label/1.png
#   inflating: FewShot/fss1000/saxophone/label/10.png
#   inflating: FewShot/fss1000/saxophone/label/2.png
#   inflating: FewShot/fss1000/saxophone/label/3.png
#   inflating: FewShot/fss1000/saxophone/label/4.png
#   inflating: FewShot/fss1000/saxophone/label/5.png
#   inflating: FewShot/fss1000/saxophone/label/6.png
#   inflating: FewShot/fss1000/saxophone/label/7.png
#   inflating: FewShot/fss1000/saxophone/label/8.png
#   inflating: FewShot/fss1000/saxophone/label/9.png
#    creating: FewShot/fss1000/scabbard/
#    creating: FewShot/fss1000/scabbard/image/
#   inflating: FewShot/fss1000/scabbard/image/1.jpg
#   inflating: FewShot/fss1000/scabbard/image/10.jpg
#   inflating: FewShot/fss1000/scabbard/image/2.jpg
#   inflating: FewShot/fss1000/scabbard/image/3.jpg
#   inflating: FewShot/fss1000/scabbard/image/4.jpg
#   inflating: FewShot/fss1000/scabbard/image/5.jpg
#   inflating: FewShot/fss1000/scabbard/image/6.jpg
#   inflating: FewShot/fss1000/scabbard/image/7.jpg
#   inflating: FewShot/fss1000/scabbard/image/8.jpg
#   inflating: FewShot/fss1000/scabbard/image/9.jpg
#    creating: FewShot/fss1000/scabbard/label/
#   inflating: FewShot/fss1000/scabbard/label/1.png
#   inflating: FewShot/fss1000/scabbard/label/10.png
#   inflating: FewShot/fss1000/scabbard/label/2.png
#   inflating: FewShot/fss1000/scabbard/label/3.png
#   inflating: FewShot/fss1000/scabbard/label/4.png
#   inflating: FewShot/fss1000/scabbard/label/5.png
#   inflating: FewShot/fss1000/scabbard/label/6.png
#   inflating: FewShot/fss1000/scabbard/label/7.png
#   inflating: FewShot/fss1000/scabbard/label/8.png
#   inflating: FewShot/fss1000/scabbard/label/9.png
#    creating: FewShot/fss1000/scarerow/
#    creating: FewShot/fss1000/scarerow/image/
#   inflating: FewShot/fss1000/scarerow/image/1.jpg
#   inflating: FewShot/fss1000/scarerow/image/10.jpg
#   inflating: FewShot/fss1000/scarerow/image/2.jpg
#   inflating: FewShot/fss1000/scarerow/image/3.jpg
#   inflating: FewShot/fss1000/scarerow/image/4.jpg
#   inflating: FewShot/fss1000/scarerow/image/5.jpg
#   inflating: FewShot/fss1000/scarerow/image/6.jpg
#   inflating: FewShot/fss1000/scarerow/image/7.jpg
#   inflating: FewShot/fss1000/scarerow/image/8.jpg
#   inflating: FewShot/fss1000/scarerow/image/9.jpg
#    creating: FewShot/fss1000/scarerow/label/
#   inflating: FewShot/fss1000/scarerow/label/1.png
#   inflating: FewShot/fss1000/scarerow/label/10.png
#   inflating: FewShot/fss1000/scarerow/label/2.png
#   inflating: FewShot/fss1000/scarerow/label/3.png
#   inflating: FewShot/fss1000/scarerow/label/4.png
#   inflating: FewShot/fss1000/scarerow/label/5.png
#   inflating: FewShot/fss1000/scarerow/label/6.png
#   inflating: FewShot/fss1000/scarerow/label/7.png
#   inflating: FewShot/fss1000/scarerow/label/8.png
#   inflating: FewShot/fss1000/scarerow/label/9.png
#    creating: FewShot/fss1000/school_bus/
#    creating: FewShot/fss1000/school_bus/image/
#   inflating: FewShot/fss1000/school_bus/image/1.jpg
#   inflating: FewShot/fss1000/school_bus/image/10.jpg
#   inflating: FewShot/fss1000/school_bus/image/2.jpg
#   inflating: FewShot/fss1000/school_bus/image/3.jpg
#   inflating: FewShot/fss1000/school_bus/image/4.jpg
#   inflating: FewShot/fss1000/school_bus/image/5.jpg
#   inflating: FewShot/fss1000/school_bus/image/6.jpg
#   inflating: FewShot/fss1000/school_bus/image/7.jpg
#   inflating: FewShot/fss1000/school_bus/image/8.jpg
#   inflating: FewShot/fss1000/school_bus/image/9.jpg
#    creating: FewShot/fss1000/school_bus/label/
#   inflating: FewShot/fss1000/school_bus/label/1.png
#   inflating: FewShot/fss1000/school_bus/label/10.png
#   inflating: FewShot/fss1000/school_bus/label/2.png
#   inflating: FewShot/fss1000/school_bus/label/3.png
#   inflating: FewShot/fss1000/school_bus/label/4.png
#   inflating: FewShot/fss1000/school_bus/label/5.png
#   inflating: FewShot/fss1000/school_bus/label/6.png
#   inflating: FewShot/fss1000/school_bus/label/7.png
#   inflating: FewShot/fss1000/school_bus/label/8.png
#   inflating: FewShot/fss1000/school_bus/label/9.png
#    creating: FewShot/fss1000/schooner/
#    creating: FewShot/fss1000/schooner/image/
#   inflating: FewShot/fss1000/schooner/image/1.jpg
#   inflating: FewShot/fss1000/schooner/image/10.jpg
#   inflating: FewShot/fss1000/schooner/image/2.jpg
#   inflating: FewShot/fss1000/schooner/image/3.jpg
#   inflating: FewShot/fss1000/schooner/image/4.jpg
#   inflating: FewShot/fss1000/schooner/image/5.jpg
#   inflating: FewShot/fss1000/schooner/image/6.jpg
#   inflating: FewShot/fss1000/schooner/image/7.jpg
#   inflating: FewShot/fss1000/schooner/image/8.jpg
#   inflating: FewShot/fss1000/schooner/image/9.jpg
#    creating: FewShot/fss1000/schooner/label/
#   inflating: FewShot/fss1000/schooner/label/1.png
#   inflating: FewShot/fss1000/schooner/label/10.png
#   inflating: FewShot/fss1000/schooner/label/2.png
#   inflating: FewShot/fss1000/schooner/label/3.png
#   inflating: FewShot/fss1000/schooner/label/4.png
#   inflating: FewShot/fss1000/schooner/label/5.png
#   inflating: FewShot/fss1000/schooner/label/6.png
#   inflating: FewShot/fss1000/schooner/label/7.png
#   inflating: FewShot/fss1000/schooner/label/8.png
#   inflating: FewShot/fss1000/schooner/label/9.png
#    creating: FewShot/fss1000/scissors/
#    creating: FewShot/fss1000/scissors/image/
#   inflating: FewShot/fss1000/scissors/image/1.jpg
#   inflating: FewShot/fss1000/scissors/image/10.jpg
#   inflating: FewShot/fss1000/scissors/image/2.jpg
#   inflating: FewShot/fss1000/scissors/image/3.jpg
#   inflating: FewShot/fss1000/scissors/image/4.jpg
#   inflating: FewShot/fss1000/scissors/image/5.jpg
#   inflating: FewShot/fss1000/scissors/image/6.jpg
#   inflating: FewShot/fss1000/scissors/image/7.jpg
#   inflating: FewShot/fss1000/scissors/image/8.jpg
#   inflating: FewShot/fss1000/scissors/image/9.jpg
#    creating: FewShot/fss1000/scissors/label/
#   inflating: FewShot/fss1000/scissors/label/1.png
#   inflating: FewShot/fss1000/scissors/label/10.png
#   inflating: FewShot/fss1000/scissors/label/2.png
#   inflating: FewShot/fss1000/scissors/label/3.png
#   inflating: FewShot/fss1000/scissors/label/4.png
#   inflating: FewShot/fss1000/scissors/label/5.png
#   inflating: FewShot/fss1000/scissors/label/6.png
#   inflating: FewShot/fss1000/scissors/label/7.png
#   inflating: FewShot/fss1000/scissors/label/8.png
#   inflating: FewShot/fss1000/scissors/label/9.png
#    creating: FewShot/fss1000/scorpion/
#    creating: FewShot/fss1000/scorpion/image/
#   inflating: FewShot/fss1000/scorpion/image/1.jpg
#   inflating: FewShot/fss1000/scorpion/image/10.jpg
#   inflating: FewShot/fss1000/scorpion/image/2.jpg
#   inflating: FewShot/fss1000/scorpion/image/3.jpg
#   inflating: FewShot/fss1000/scorpion/image/4.jpg
#   inflating: FewShot/fss1000/scorpion/image/5.jpg
#   inflating: FewShot/fss1000/scorpion/image/6.jpg
#   inflating: FewShot/fss1000/scorpion/image/7.jpg
#   inflating: FewShot/fss1000/scorpion/image/8.jpg
#   inflating: FewShot/fss1000/scorpion/image/9.jpg
#    creating: FewShot/fss1000/scorpion/label/
#   inflating: FewShot/fss1000/scorpion/label/1.png
#   inflating: FewShot/fss1000/scorpion/label/10.png
#   inflating: FewShot/fss1000/scorpion/label/2.png
#   inflating: FewShot/fss1000/scorpion/label/3.png
#   inflating: FewShot/fss1000/scorpion/label/4.png
#   inflating: FewShot/fss1000/scorpion/label/5.png
#   inflating: FewShot/fss1000/scorpion/label/6.png
#   inflating: FewShot/fss1000/scorpion/label/7.png
#   inflating: FewShot/fss1000/scorpion/label/8.png
#   inflating: FewShot/fss1000/scorpion/label/9.png
#    creating: FewShot/fss1000/screwdriver/
#    creating: FewShot/fss1000/screwdriver/image/
#   inflating: FewShot/fss1000/screwdriver/image/1.jpg
#   inflating: FewShot/fss1000/screwdriver/image/10.jpg
#   inflating: FewShot/fss1000/screwdriver/image/2.jpg
#   inflating: FewShot/fss1000/screwdriver/image/3.jpg
#   inflating: FewShot/fss1000/screwdriver/image/4.jpg
#   inflating: FewShot/fss1000/screwdriver/image/5.jpg
#   inflating: FewShot/fss1000/screwdriver/image/6.jpg
#   inflating: FewShot/fss1000/screwdriver/image/7.jpg
#   inflating: FewShot/fss1000/screwdriver/image/8.jpg
#   inflating: FewShot/fss1000/screwdriver/image/9.jpg
#    creating: FewShot/fss1000/screwdriver/label/
#   inflating: FewShot/fss1000/screwdriver/label/1.png
#   inflating: FewShot/fss1000/screwdriver/label/10.png
#   inflating: FewShot/fss1000/screwdriver/label/2.png
#   inflating: FewShot/fss1000/screwdriver/label/3.png
#   inflating: FewShot/fss1000/screwdriver/label/4.png
#   inflating: FewShot/fss1000/screwdriver/label/5.png
#   inflating: FewShot/fss1000/screwdriver/label/6.png
#   inflating: FewShot/fss1000/screwdriver/label/7.png
#   inflating: FewShot/fss1000/screwdriver/label/8.png
#   inflating: FewShot/fss1000/screwdriver/label/9.png
#    creating: FewShot/fss1000/scroll_brush/
#    creating: FewShot/fss1000/scroll_brush/image/
#   inflating: FewShot/fss1000/scroll_brush/image/1.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/10.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/2.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/3.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/4.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/5.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/6.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/7.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/8.jpg
#   inflating: FewShot/fss1000/scroll_brush/image/9.jpg
#    creating: FewShot/fss1000/scroll_brush/label/
#   inflating: FewShot/fss1000/scroll_brush/label/1.png
#   inflating: FewShot/fss1000/scroll_brush/label/10.png
#   inflating: FewShot/fss1000/scroll_brush/label/2.png
#   inflating: FewShot/fss1000/scroll_brush/label/3.png
#   inflating: FewShot/fss1000/scroll_brush/label/4.png
#   inflating: FewShot/fss1000/scroll_brush/label/5.png
#   inflating: FewShot/fss1000/scroll_brush/label/6.png
#   inflating: FewShot/fss1000/scroll_brush/label/7.png
#   inflating: FewShot/fss1000/scroll_brush/label/8.png
#   inflating: FewShot/fss1000/scroll_brush/label/9.png
#    creating: FewShot/fss1000/sea_cucumber/
#    creating: FewShot/fss1000/sea_cucumber/image/
#   inflating: FewShot/fss1000/sea_cucumber/image/1.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/10.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/2.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/3.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/4.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/5.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/6.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/7.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/8.jpg
#   inflating: FewShot/fss1000/sea_cucumber/image/9.jpg
#    creating: FewShot/fss1000/sea_cucumber/label/
#   inflating: FewShot/fss1000/sea_cucumber/label/1.png
#   inflating: FewShot/fss1000/sea_cucumber/label/10.png
#   inflating: FewShot/fss1000/sea_cucumber/label/2.png
#   inflating: FewShot/fss1000/sea_cucumber/label/3.png
#   inflating: FewShot/fss1000/sea_cucumber/label/4.png
#   inflating: FewShot/fss1000/sea_cucumber/label/5.png
#   inflating: FewShot/fss1000/sea_cucumber/label/6.png
#   inflating: FewShot/fss1000/sea_cucumber/label/7.png
#   inflating: FewShot/fss1000/sea_cucumber/label/8.png
#   inflating: FewShot/fss1000/sea_cucumber/label/9.png
#    creating: FewShot/fss1000/sea_urchin/
#    creating: FewShot/fss1000/sea_urchin/image/
#   inflating: FewShot/fss1000/sea_urchin/image/1.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/10.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/2.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/3.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/4.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/5.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/6.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/7.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/8.jpg
#   inflating: FewShot/fss1000/sea_urchin/image/9.jpg
#    creating: FewShot/fss1000/sea_urchin/label/
#   inflating: FewShot/fss1000/sea_urchin/label/1.png
#   inflating: FewShot/fss1000/sea_urchin/label/10.png
#   inflating: FewShot/fss1000/sea_urchin/label/2.png
#   inflating: FewShot/fss1000/sea_urchin/label/3.png
#   inflating: FewShot/fss1000/sea_urchin/label/4.png
#   inflating: FewShot/fss1000/sea_urchin/label/5.png
#   inflating: FewShot/fss1000/sea_urchin/label/6.png
#   inflating: FewShot/fss1000/sea_urchin/label/7.png
#   inflating: FewShot/fss1000/sea_urchin/label/8.png
#   inflating: FewShot/fss1000/sea_urchin/label/9.png
#    creating: FewShot/fss1000/seal/
#    creating: FewShot/fss1000/seal/image/
#   inflating: FewShot/fss1000/seal/image/1.jpg
#   inflating: FewShot/fss1000/seal/image/10.jpg
#   inflating: FewShot/fss1000/seal/image/2.jpg
#   inflating: FewShot/fss1000/seal/image/3.jpg
#   inflating: FewShot/fss1000/seal/image/4.jpg
#   inflating: FewShot/fss1000/seal/image/5.jpg
#   inflating: FewShot/fss1000/seal/image/6.jpg
#   inflating: FewShot/fss1000/seal/image/7.jpg
#   inflating: FewShot/fss1000/seal/image/8.jpg
#   inflating: FewShot/fss1000/seal/image/9.jpg
#    creating: FewShot/fss1000/seal/label/
#   inflating: FewShot/fss1000/seal/label/1.png
#   inflating: FewShot/fss1000/seal/label/10.png
#   inflating: FewShot/fss1000/seal/label/2.png
#   inflating: FewShot/fss1000/seal/label/3.png
#   inflating: FewShot/fss1000/seal/label/4.png
#   inflating: FewShot/fss1000/seal/label/5.png
#   inflating: FewShot/fss1000/seal/label/6.png
#   inflating: FewShot/fss1000/seal/label/7.png
#   inflating: FewShot/fss1000/seal/label/8.png
#   inflating: FewShot/fss1000/seal/label/9.png
#    creating: FewShot/fss1000/seatbelt/
#    creating: FewShot/fss1000/seatbelt/image/
#   inflating: FewShot/fss1000/seatbelt/image/1.jpg
#   inflating: FewShot/fss1000/seatbelt/image/10.jpg
#   inflating: FewShot/fss1000/seatbelt/image/2.jpg
#   inflating: FewShot/fss1000/seatbelt/image/3.jpg
#   inflating: FewShot/fss1000/seatbelt/image/4.jpg
#   inflating: FewShot/fss1000/seatbelt/image/5.jpg
#   inflating: FewShot/fss1000/seatbelt/image/6.jpg
#   inflating: FewShot/fss1000/seatbelt/image/7.jpg
#   inflating: FewShot/fss1000/seatbelt/image/8.jpg
#   inflating: FewShot/fss1000/seatbelt/image/9.jpg
#    creating: FewShot/fss1000/seatbelt/label/
#   inflating: FewShot/fss1000/seatbelt/label/1.png
#   inflating: FewShot/fss1000/seatbelt/label/10.png
#   inflating: FewShot/fss1000/seatbelt/label/2.png
#   inflating: FewShot/fss1000/seatbelt/label/3.png
#   inflating: FewShot/fss1000/seatbelt/label/4.png
#   inflating: FewShot/fss1000/seatbelt/label/5.png
#   inflating: FewShot/fss1000/seatbelt/label/6.png
#   inflating: FewShot/fss1000/seatbelt/label/7.png
#   inflating: FewShot/fss1000/seatbelt/label/8.png
#   inflating: FewShot/fss1000/seatbelt/label/9.png
#    creating: FewShot/fss1000/sewing_machine/
#    creating: FewShot/fss1000/sewing_machine/image/
#   inflating: FewShot/fss1000/sewing_machine/image/1.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/10.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/2.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/3.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/4.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/5.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/6.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/7.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/8.jpg
#   inflating: FewShot/fss1000/sewing_machine/image/9.jpg
#    creating: FewShot/fss1000/sewing_machine/label/
#   inflating: FewShot/fss1000/sewing_machine/label/1.png
#   inflating: FewShot/fss1000/sewing_machine/label/10.png
#   inflating: FewShot/fss1000/sewing_machine/label/2.png
#   inflating: FewShot/fss1000/sewing_machine/label/3.png
#   inflating: FewShot/fss1000/sewing_machine/label/4.png
#   inflating: FewShot/fss1000/sewing_machine/label/5.png
#   inflating: FewShot/fss1000/sewing_machine/label/6.png
#   inflating: FewShot/fss1000/sewing_machine/label/7.png
#   inflating: FewShot/fss1000/sewing_machine/label/8.png
#   inflating: FewShot/fss1000/sewing_machine/label/9.png
#    creating: FewShot/fss1000/shakuhachi/
#    creating: FewShot/fss1000/shakuhachi/image/
#   inflating: FewShot/fss1000/shakuhachi/image/1.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/10.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/2.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/3.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/4.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/5.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/6.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/7.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/8.jpg
#   inflating: FewShot/fss1000/shakuhachi/image/9.jpg
#    creating: FewShot/fss1000/shakuhachi/label/
#   inflating: FewShot/fss1000/shakuhachi/label/1.png
#   inflating: FewShot/fss1000/shakuhachi/label/10.png
#   inflating: FewShot/fss1000/shakuhachi/label/2.png
#   inflating: FewShot/fss1000/shakuhachi/label/3.png
#   inflating: FewShot/fss1000/shakuhachi/label/4.png
#   inflating: FewShot/fss1000/shakuhachi/label/5.png
#   inflating: FewShot/fss1000/shakuhachi/label/6.png
#   inflating: FewShot/fss1000/shakuhachi/label/7.png
#   inflating: FewShot/fss1000/shakuhachi/label/8.png
#   inflating: FewShot/fss1000/shakuhachi/label/9.png
#    creating: FewShot/fss1000/shift_gear/
#    creating: FewShot/fss1000/shift_gear/image/
#   inflating: FewShot/fss1000/shift_gear/image/1.jpg
#   inflating: FewShot/fss1000/shift_gear/image/10.jpg
#   inflating: FewShot/fss1000/shift_gear/image/2.jpg
#   inflating: FewShot/fss1000/shift_gear/image/3.jpg
#   inflating: FewShot/fss1000/shift_gear/image/4.jpg
#   inflating: FewShot/fss1000/shift_gear/image/5.jpg
#   inflating: FewShot/fss1000/shift_gear/image/6.jpg
#   inflating: FewShot/fss1000/shift_gear/image/7.jpg
#   inflating: FewShot/fss1000/shift_gear/image/8.jpg
#   inflating: FewShot/fss1000/shift_gear/image/9.jpg
#    creating: FewShot/fss1000/shift_gear/label/
#   inflating: FewShot/fss1000/shift_gear/label/1.png
#   inflating: FewShot/fss1000/shift_gear/label/10.png
#   inflating: FewShot/fss1000/shift_gear/label/2.png
#   inflating: FewShot/fss1000/shift_gear/label/3.png
#   inflating: FewShot/fss1000/shift_gear/label/4.png
#   inflating: FewShot/fss1000/shift_gear/label/5.png
#   inflating: FewShot/fss1000/shift_gear/label/6.png
#   inflating: FewShot/fss1000/shift_gear/label/7.png
#   inflating: FewShot/fss1000/shift_gear/label/8.png
#   inflating: FewShot/fss1000/shift_gear/label/9.png
#    creating: FewShot/fss1000/shih-tzu/
#    creating: FewShot/fss1000/shih-tzu/image/
#   inflating: FewShot/fss1000/shih-tzu/image/1.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/10.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/2.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/3.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/4.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/5.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/6.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/7.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/8.jpg
#   inflating: FewShot/fss1000/shih-tzu/image/9.jpg
#    creating: FewShot/fss1000/shih-tzu/label/
#   inflating: FewShot/fss1000/shih-tzu/label/1.png
#   inflating: FewShot/fss1000/shih-tzu/label/10.png
#   inflating: FewShot/fss1000/shih-tzu/label/2.png
#   inflating: FewShot/fss1000/shih-tzu/label/3.png
#   inflating: FewShot/fss1000/shih-tzu/label/4.png
#   inflating: FewShot/fss1000/shih-tzu/label/5.png
#   inflating: FewShot/fss1000/shih-tzu/label/6.png
#   inflating: FewShot/fss1000/shih-tzu/label/7.png
#   inflating: FewShot/fss1000/shih-tzu/label/8.png
#   inflating: FewShot/fss1000/shih-tzu/label/9.png
#    creating: FewShot/fss1000/shopping_cart/
#    creating: FewShot/fss1000/shopping_cart/image/
#   inflating: FewShot/fss1000/shopping_cart/image/1.jpg
# ...
#   inflating: FewShot/fss1000/wine_bottle/image/3.jpg
#   inflating: FewShot/fss1000/wine_bottle/image/4.jpg
#   inflating: FewShot/fss1000/wine_bottle/image/5.jpg
#   inflating: FewShot/fss1000/wine_bottle/image/6.jpg
#   inflating: FewShot/fss1000/wine_bottle/image/7.jpg
#   inflating: FewShot/fss1000/wine_bottle/image/8.jpg
#   inflating: FewShot/fss1000/wine_bottle/image/9.jpg
#    creating: FewShot/fss1000/wine_bottle/label/
#   inflating: FewShot/fss1000/wine_bottle/label/1.png
#   inflating: FewShot/fss1000/wine_bottle/label/10.png
#   inflating: FewShot/fss1000/wine_bottle/label/2.png
#   inflating: FewShot/fss1000/wine_bottle/label/3.png
#   inflating: FewShot/fss1000/wine_bottle/label/4.png
#   inflating: FewShot/fss1000/wine_bottle/label/5.png
#   inflating: FewShot/fss1000/wine_bottle/label/6.png
#   inflating: FewShot/fss1000/wine_bottle/label/7.png
#   inflating: FewShot/fss1000/wine_bottle/label/8.png
#   inflating: FewShot/fss1000/wine_bottle/label/9.png
#    creating: FewShot/fss1000/witch_hat/
#    creating: FewShot/fss1000/witch_hat/image/
#   inflating: FewShot/fss1000/witch_hat/image/1.jpg
#   inflating: FewShot/fss1000/witch_hat/image/10.jpg
#   inflating: FewShot/fss1000/witch_hat/image/2.jpg
#   inflating: FewShot/fss1000/witch_hat/image/3.jpg
#   inflating: FewShot/fss1000/witch_hat/image/4.jpg
#   inflating: FewShot/fss1000/witch_hat/image/5.jpg
#   inflating: FewShot/fss1000/witch_hat/image/6.jpg
#   inflating: FewShot/fss1000/witch_hat/image/7.jpg
#   inflating: FewShot/fss1000/witch_hat/image/8.jpg
#   inflating: FewShot/fss1000/witch_hat/image/9.jpg
#    creating: FewShot/fss1000/witch_hat/label/
#   inflating: FewShot/fss1000/witch_hat/label/1.png
#   inflating: FewShot/fss1000/witch_hat/label/10.png
#   inflating: FewShot/fss1000/witch_hat/label/2.png
#   inflating: FewShot/fss1000/witch_hat/label/3.png
#   inflating: FewShot/fss1000/witch_hat/label/4.png
#   inflating: FewShot/fss1000/witch_hat/label/5.png
#   inflating: FewShot/fss1000/witch_hat/label/6.png
#   inflating: FewShot/fss1000/witch_hat/label/7.png
#   inflating: FewShot/fss1000/witch_hat/label/8.png
#   inflating: FewShot/fss1000/witch_hat/label/9.png
#    creating: FewShot/fss1000/wok/
#    creating: FewShot/fss1000/wok/image/
#   inflating: FewShot/fss1000/wok/image/1.jpg
#   inflating: FewShot/fss1000/wok/image/10.jpg
#   inflating: FewShot/fss1000/wok/image/2.jpg
#   inflating: FewShot/fss1000/wok/image/3.jpg
#   inflating: FewShot/fss1000/wok/image/4.jpg
#   inflating: FewShot/fss1000/wok/image/5.jpg
#   inflating: FewShot/fss1000/wok/image/6.jpg
#   inflating: FewShot/fss1000/wok/image/7.jpg
#   inflating: FewShot/fss1000/wok/image/8.jpg
#   inflating: FewShot/fss1000/wok/image/9.jpg
#    creating: FewShot/fss1000/wok/label/
#   inflating: FewShot/fss1000/wok/label/1.png
#   inflating: FewShot/fss1000/wok/label/10.png
#   inflating: FewShot/fss1000/wok/label/2.png
#   inflating: FewShot/fss1000/wok/label/3.png
#   inflating: FewShot/fss1000/wok/label/4.png
#   inflating: FewShot/fss1000/wok/label/5.png
#   inflating: FewShot/fss1000/wok/label/6.png
#   inflating: FewShot/fss1000/wok/label/7.png
#   inflating: FewShot/fss1000/wok/label/8.png
#   inflating: FewShot/fss1000/wok/label/9.png
#    creating: FewShot/fss1000/wolf/
#    creating: FewShot/fss1000/wolf/image/
#   inflating: FewShot/fss1000/wolf/image/1.jpg
#   inflating: FewShot/fss1000/wolf/image/10.jpg
#   inflating: FewShot/fss1000/wolf/image/2.jpg
#   inflating: FewShot/fss1000/wolf/image/3.jpg
#   inflating: FewShot/fss1000/wolf/image/4.jpg
#   inflating: FewShot/fss1000/wolf/image/5.jpg
#   inflating: FewShot/fss1000/wolf/image/6.jpg
#   inflating: FewShot/fss1000/wolf/image/7.jpg
#   inflating: FewShot/fss1000/wolf/image/8.jpg
#   inflating: FewShot/fss1000/wolf/image/9.jpg
#    creating: FewShot/fss1000/wolf/label/
#   inflating: FewShot/fss1000/wolf/label/1.png
#   inflating: FewShot/fss1000/wolf/label/10.png
#   inflating: FewShot/fss1000/wolf/label/2.png
#   inflating: FewShot/fss1000/wolf/label/3.png
#   inflating: FewShot/fss1000/wolf/label/4.png
#   inflating: FewShot/fss1000/wolf/label/5.png
#   inflating: FewShot/fss1000/wolf/label/6.png
#   inflating: FewShot/fss1000/wolf/label/7.png
#   inflating: FewShot/fss1000/wolf/label/8.png
#   inflating: FewShot/fss1000/wolf/label/9.png
#    creating: FewShot/fss1000/wombat/
#    creating: FewShot/fss1000/wombat/image/
#   inflating: FewShot/fss1000/wombat/image/1.jpg
#   inflating: FewShot/fss1000/wombat/image/10.jpg
#   inflating: FewShot/fss1000/wombat/image/2.jpg
#   inflating: FewShot/fss1000/wombat/image/3.jpg
#   inflating: FewShot/fss1000/wombat/image/4.jpg
#   inflating: FewShot/fss1000/wombat/image/5.jpg
#   inflating: FewShot/fss1000/wombat/image/6.jpg
#   inflating: FewShot/fss1000/wombat/image/7.jpg
#   inflating: FewShot/fss1000/wombat/image/8.jpg
#   inflating: FewShot/fss1000/wombat/image/9.jpg
#    creating: FewShot/fss1000/wombat/label/
#   inflating: FewShot/fss1000/wombat/label/1.png
#   inflating: FewShot/fss1000/wombat/label/10.png
#   inflating: FewShot/fss1000/wombat/label/2.png
#   inflating: FewShot/fss1000/wombat/label/3.png
#   inflating: FewShot/fss1000/wombat/label/4.png
#   inflating: FewShot/fss1000/wombat/label/5.png
#   inflating: FewShot/fss1000/wombat/label/6.png
#   inflating: FewShot/fss1000/wombat/label/7.png
#   inflating: FewShot/fss1000/wombat/label/8.png
#   inflating: FewShot/fss1000/wombat/label/9.png
#    creating: FewShot/fss1000/woodpecker/
#    creating: FewShot/fss1000/woodpecker/image/
#   inflating: FewShot/fss1000/woodpecker/image/1.jpg
#   inflating: FewShot/fss1000/woodpecker/image/10.jpg
#   inflating: FewShot/fss1000/woodpecker/image/2.jpg
#   inflating: FewShot/fss1000/woodpecker/image/3.jpg
#   inflating: FewShot/fss1000/woodpecker/image/4.jpg
#   inflating: FewShot/fss1000/woodpecker/image/5.jpg
#   inflating: FewShot/fss1000/woodpecker/image/6.jpg
#   inflating: FewShot/fss1000/woodpecker/image/7.jpg
#   inflating: FewShot/fss1000/woodpecker/image/8.jpg
#   inflating: FewShot/fss1000/woodpecker/image/9.jpg
#    creating: FewShot/fss1000/woodpecker/label/
#   inflating: FewShot/fss1000/woodpecker/label/1.png
#   inflating: FewShot/fss1000/woodpecker/label/10.png
#   inflating: FewShot/fss1000/woodpecker/label/2.png
#   inflating: FewShot/fss1000/woodpecker/label/3.png
#   inflating: FewShot/fss1000/woodpecker/label/4.png
#   inflating: FewShot/fss1000/woodpecker/label/5.png
#   inflating: FewShot/fss1000/woodpecker/label/6.png
#   inflating: FewShot/fss1000/woodpecker/label/7.png
#   inflating: FewShot/fss1000/woodpecker/label/8.png
#   inflating: FewShot/fss1000/woodpecker/label/9.png
#    creating: FewShot/fss1000/wreck/
#    creating: FewShot/fss1000/wreck/image/
#   inflating: FewShot/fss1000/wreck/image/1.jpg
#   inflating: FewShot/fss1000/wreck/image/10.jpg
#   inflating: FewShot/fss1000/wreck/image/2.jpg
#   inflating: FewShot/fss1000/wreck/image/3.jpg
#   inflating: FewShot/fss1000/wreck/image/4.jpg
#   inflating: FewShot/fss1000/wreck/image/5.jpg
#   inflating: FewShot/fss1000/wreck/image/6.jpg
#   inflating: FewShot/fss1000/wreck/image/7.jpg
#   inflating: FewShot/fss1000/wreck/image/8.jpg
#   inflating: FewShot/fss1000/wreck/image/9.jpg
#    creating: FewShot/fss1000/wreck/label/
#   inflating: FewShot/fss1000/wreck/label/1.png
#   inflating: FewShot/fss1000/wreck/label/10.png
#   inflating: FewShot/fss1000/wreck/label/2.png
#   inflating: FewShot/fss1000/wreck/label/3.png
#   inflating: FewShot/fss1000/wreck/label/4.png
#   inflating: FewShot/fss1000/wreck/label/5.png
#   inflating: FewShot/fss1000/wreck/label/6.png
#   inflating: FewShot/fss1000/wreck/label/7.png
#   inflating: FewShot/fss1000/wreck/label/8.png
#   inflating: FewShot/fss1000/wreck/label/9.png
#    creating: FewShot/fss1000/wrench/
#    creating: FewShot/fss1000/wrench/image/
#   inflating: FewShot/fss1000/wrench/image/1.jpg
#   inflating: FewShot/fss1000/wrench/image/10.jpg
#   inflating: FewShot/fss1000/wrench/image/2.jpg
#   inflating: FewShot/fss1000/wrench/image/3.jpg
#   inflating: FewShot/fss1000/wrench/image/4.jpg
#   inflating: FewShot/fss1000/wrench/image/5.jpg
#   inflating: FewShot/fss1000/wrench/image/6.jpg
#   inflating: FewShot/fss1000/wrench/image/7.jpg
#   inflating: FewShot/fss1000/wrench/image/8.jpg
#   inflating: FewShot/fss1000/wrench/image/9.jpg
#    creating: FewShot/fss1000/wrench/label/
#   inflating: FewShot/fss1000/wrench/label/1.png
#   inflating: FewShot/fss1000/wrench/label/10.png
#   inflating: FewShot/fss1000/wrench/label/2.png
#   inflating: FewShot/fss1000/wrench/label/3.png
#   inflating: FewShot/fss1000/wrench/label/4.png
#   inflating: FewShot/fss1000/wrench/label/5.png
#   inflating: FewShot/fss1000/wrench/label/6.png
#   inflating: FewShot/fss1000/wrench/label/7.png
#   inflating: FewShot/fss1000/wrench/label/8.png
#   inflating: FewShot/fss1000/wrench/label/9.png
#    creating: FewShot/fss1000/yawl/
#    creating: FewShot/fss1000/yawl/image/
#   inflating: FewShot/fss1000/yawl/image/1.jpg
#   inflating: FewShot/fss1000/yawl/image/10.jpg
#   inflating: FewShot/fss1000/yawl/image/2.jpg
#   inflating: FewShot/fss1000/yawl/image/3.jpg
#   inflating: FewShot/fss1000/yawl/image/4.jpg
#   inflating: FewShot/fss1000/yawl/image/5.jpg
#   inflating: FewShot/fss1000/yawl/image/6.jpg
#   inflating: FewShot/fss1000/yawl/image/7.jpg
#   inflating: FewShot/fss1000/yawl/image/8.jpg
#   inflating: FewShot/fss1000/yawl/image/9.jpg
#    creating: FewShot/fss1000/yawl/label/
#   inflating: FewShot/fss1000/yawl/label/1.png
#   inflating: FewShot/fss1000/yawl/label/10.png
#   inflating: FewShot/fss1000/yawl/label/2.png
#   inflating: FewShot/fss1000/yawl/label/3.png
#   inflating: FewShot/fss1000/yawl/label/4.png
#   inflating: FewShot/fss1000/yawl/label/5.png
#   inflating: FewShot/fss1000/yawl/label/6.png
#   inflating: FewShot/fss1000/yawl/label/7.png
#   inflating: FewShot/fss1000/yawl/label/8.png
#   inflating: FewShot/fss1000/yawl/label/9.png
#    creating: FewShot/fss1000/yoga_pad/
#    creating: FewShot/fss1000/yoga_pad/image/
#   inflating: FewShot/fss1000/yoga_pad/image/1.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/10.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/2.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/3.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/4.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/5.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/6.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/7.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/8.jpg
#   inflating: FewShot/fss1000/yoga_pad/image/9.jpg
#    creating: FewShot/fss1000/yoga_pad/label/
#   inflating: FewShot/fss1000/yoga_pad/label/1.png
#   inflating: FewShot/fss1000/yoga_pad/label/10.png
#   inflating: FewShot/fss1000/yoga_pad/label/2.png
#   inflating: FewShot/fss1000/yoga_pad/label/3.png
#   inflating: FewShot/fss1000/yoga_pad/label/4.png
#   inflating: FewShot/fss1000/yoga_pad/label/5.png
#   inflating: FewShot/fss1000/yoga_pad/label/6.png
#   inflating: FewShot/fss1000/yoga_pad/label/7.png
#   inflating: FewShot/fss1000/yoga_pad/label/8.png
#   inflating: FewShot/fss1000/yoga_pad/label/9.png
#    creating: FewShot/fss1000/yonex_icon/
#    creating: FewShot/fss1000/yonex_icon/image/
#   inflating: FewShot/fss1000/yonex_icon/image/1.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/10.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/2.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/3.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/4.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/5.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/6.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/7.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/8.jpg
#   inflating: FewShot/fss1000/yonex_icon/image/9.jpg
#    creating: FewShot/fss1000/yonex_icon/label/
#   inflating: FewShot/fss1000/yonex_icon/label/1.png
#   inflating: FewShot/fss1000/yonex_icon/label/10.png
#   inflating: FewShot/fss1000/yonex_icon/label/2.png
#   inflating: FewShot/fss1000/yonex_icon/label/3.png
#   inflating: FewShot/fss1000/yonex_icon/label/4.png
#   inflating: FewShot/fss1000/yonex_icon/label/5.png
#   inflating: FewShot/fss1000/yonex_icon/label/6.png
#   inflating: FewShot/fss1000/yonex_icon/label/7.png
#   inflating: FewShot/fss1000/yonex_icon/label/8.png
#   inflating: FewShot/fss1000/yonex_icon/label/9.png
#    creating: FewShot/fss1000/yorkshire_terrier/
#    creating: FewShot/fss1000/yorkshire_terrier/image/
#   inflating: FewShot/fss1000/yorkshire_terrier/image/1.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/10.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/2.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/3.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/4.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/5.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/6.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/7.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/8.jpg
#   inflating: FewShot/fss1000/yorkshire_terrier/image/9.jpg
#    creating: FewShot/fss1000/yorkshire_terrier/label/
#   inflating: FewShot/fss1000/yorkshire_terrier/label/1.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/10.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/2.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/3.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/4.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/5.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/6.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/7.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/8.png
#   inflating: FewShot/fss1000/yorkshire_terrier/label/9.png
#    creating: FewShot/fss1000/yurt/
#    creating: FewShot/fss1000/yurt/image/
#   inflating: FewShot/fss1000/yurt/image/1.jpg
#   inflating: FewShot/fss1000/yurt/image/10.jpg
#   inflating: FewShot/fss1000/yurt/image/2.jpg
#   inflating: FewShot/fss1000/yurt/image/3.jpg
#   inflating: FewShot/fss1000/yurt/image/4.jpg
#   inflating: FewShot/fss1000/yurt/image/5.jpg
#   inflating: FewShot/fss1000/yurt/image/6.jpg
#   inflating: FewShot/fss1000/yurt/image/7.jpg
#   inflating: FewShot/fss1000/yurt/image/8.jpg
#   inflating: FewShot/fss1000/yurt/image/9.jpg
#    creating: FewShot/fss1000/yurt/label/
#   inflating: FewShot/fss1000/yurt/label/1.png
#   inflating: FewShot/fss1000/yurt/label/10.png
#   inflating: FewShot/fss1000/yurt/label/2.png
#   inflating: FewShot/fss1000/yurt/label/3.png
#   inflating: FewShot/fss1000/yurt/label/4.png
#   inflating: FewShot/fss1000/yurt/label/5.png
#   inflating: FewShot/fss1000/yurt/label/6.png
#   inflating: FewShot/fss1000/yurt/label/7.png
#   inflating: FewShot/fss1000/yurt/label/8.png
#   inflating: FewShot/fss1000/yurt/label/9.png
#    creating: FewShot/fss1000/zucchini/
#    creating: FewShot/fss1000/zucchini/image/
#   inflating: FewShot/fss1000/zucchini/image/1.jpg
#   inflating: FewShot/fss1000/zucchini/image/10.jpg
#   inflating: FewShot/fss1000/zucchini/image/2.jpg
#   inflating: FewShot/fss1000/zucchini/image/3.jpg
#   inflating: FewShot/fss1000/zucchini/image/4.jpg
#   inflating: FewShot/fss1000/zucchini/image/5.jpg
#   inflating: FewShot/fss1000/zucchini/image/6.jpg
#   inflating: FewShot/fss1000/zucchini/image/7.jpg
#   inflating: FewShot/fss1000/zucchini/image/8.jpg
#   inflating: FewShot/fss1000/zucchini/image/9.jpg
#    creating: FewShot/fss1000/zucchini/label/
#   inflating: FewShot/fss1000/zucchini/label/1.png
#   inflating: FewShot/fss1000/zucchini/label/10.png
#   inflating: FewShot/fss1000/zucchini/label/2.png
#   inflating: FewShot/fss1000/zucchini/label/3.png
#   inflating: FewShot/fss1000/zucchini/label/4.png
#   inflating: FewShot/fss1000/zucchini/label/5.png
#   inflating: FewShot/fss1000/zucchini/label/6.png
#   inflating: FewShot/fss1000/zucchini/label/7.png
#   inflating: FewShot/fss1000/zucchini/label/8.png
#   inflating: FewShot/fss1000/zucchini/label/9.png

# %%
# !ls
# Out:
# drive  FewShot	sample_data

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR
import torchvision.models as models
import numpy as np
import os
import subprocess
import math
import argparse
import random
import cv2
import sys
sys.argv=['']
del sys

parser = argparse.ArgumentParser(description="One Shot Visual Recognition")
parser.add_argument("-w","--class_num",type = int, default = 1)
parser.add_argument("-s","--sample_num_per_class",type = int, default = 5)
parser.add_argument("-b","--batch_num_per_class",type = int, default = 5)
parser.add_argument("-e","--episode",type = int, default= 500000)
parser.add_argument("-t","--test_episode", type = int, default = 1000)
parser.add_argument("-l","--learning_rate", type = float, default = 0.001)
parser.add_argument("-rf","--TrainResultPath",type=str,default='result_newvgg_1shot')
parser.add_argument("-rff","--ResultSaveFreq",type=int,default=10000)
parser.add_argument("-msp","--ModelSavePath",type=str,default='models_newvgg_1shot')
parser.add_argument("-msf","--ModelSaveFreq",type=int,default=10000)
parser.add_argument("-g","--gpu",type=int, default=0)
parser.add_argument("-d","--display_query_num",type=int,default=5)
parser.add_argument("-modelf","--encoder_model",type=str,default='')
parser.add_argument("-modeld","--decoder_model",type=str,default='')
parser.add_argument("-modelh","--head_model",type=str,default='')
parser.add_argument("-start","--start_episode",type = int, default= 0)
parser.add_argument("-fi","--finetune",type=bool,default=True)



args = parser.parse_args()



## Hyper Parameters

CLASS_NUM = args.class_num
SAMPLE_NUM_PER_CLASS = args.sample_num_per_class
BATCH_NUM_PER_CLASS = args.batch_num_per_class
EPISODE = args.episode
TEST_EPISODE = args.test_episode
LEARNING_RATE = args.learning_rate
GPU = args.gpu
DISPLAY_QUERY = args.display_query_num
ENCODER_MODEL = args.encoder_model
DECODER_MODEL = args.decoder_model
HEAD_MODEL = args.head_model

# %%
import torch
import torch.nn as nn


def patch_first_conv(model, in_channels):
    """Change first convolution layer input channels.
    In case:
        in_channels == 1 or in_channels == 2 -> reuse original weights
        in_channels > 3 -> make random kaiming normal initialization
    """

    # get first conv
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            break

    # change input channels for first conv
    module.in_channels = in_channels
    weight = module.weight.detach()
    reset = False

    if in_channels == 1:
        weight = weight.sum(1, keepdim=True)
    elif in_channels == 2:
        weight = weight[:, :2] * (3.0 / 2.0)
    else:
        reset = True
        weight = torch.Tensor(
            module.out_channels,
            module.in_channels // module.groups,
            *module.kernel_size
        )

    module.weight = nn.parameter.Parameter(weight)
    if reset:
        module.reset_parameters()


def replace_strides_with_dilation(module, dilation_rate):
    """Patch Conv2d modules replacing strides with dilation"""
    for mod in module.modules():
        if isinstance(mod, nn.Conv2d):
            mod.stride = (1, 1)
            mod.dilation = (dilation_rate, dilation_rate)
            kh, kw = mod.kernel_size
            mod.padding = ((kh // 2) * dilation_rate, (kh // 2) * dilation_rate)

            # Kostyl for EfficientNet
            if hasattr(mod, "static_padding"):
                mod.static_padding = nn.Identity()

# %%
import torch
import torch.nn as nn
from typing import List
from collections import OrderedDict



class EncoderMixin:
    """Add encoder functionality such as:
        - output channels specification of feature tensors (produced by encoder)
        - patching first convolution for arbitrary input channels
    """

    @property
    def out_channels(self):
        """Return channels dimensions for each tensor of forward output of encoder"""
        return self._out_channels[: self._depth + 1]

    def set_in_channels(self, in_channels):
        """Change first convolution channels"""
        if in_channels == 3:
            return

        self._in_channels = in_channels
        if self._out_channels[0] == 3:
            self._out_channels = tuple([in_channels] + list(self._out_channels)[1:])

        patch_first_conv(model=self, in_channels=in_channels)

    def get_stages(self):
        """Method should be overridden in encoder"""
        raise NotImplementedError

    def make_dilated(self, stage_list, dilation_list):
        stages = self.get_stages()
        for stage_indx, dilation_rate in zip(stage_list, dilation_list):
            replace_strides_with_dilation(
                module=stages[stage_indx],
                dilation_rate=dilation_rate,
            )

# %% [markdown]
# # Concurrent Channel and Spatial Excitation

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ChannelSELayer(nn.Module):
    """
    Re-implementation of Squeeze-and-Excitation (SE) block described in:
        *Hu et al., Squeeze-and-Excitation Networks, arXiv:1709.01507*
    """

    def __init__(self, num_channels, reduction_ratio=2):
        """
        :param num_channels: No of input channels
        :param reduction_ratio: By how much should the num_channels should be reduced
        """
        super(ChannelSELayer, self).__init__()
        num_channels_reduced = num_channels // reduction_ratio
        self.reduction_ratio = reduction_ratio
        self.fc1 = nn.Linear(num_channels, num_channels_reduced, bias=True)
        self.fc2 = nn.Linear(num_channels_reduced, num_channels, bias=True)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_tensor):
        """
        :param input_tensor: X, shape = (batch_size, num_channels, H, W)
        :return: output tensor
        """
        batch_size, num_channels, H, W = input_tensor.size()
        # Average along each channel
        squeeze_tensor = input_tensor.view(batch_size, num_channels, -1).mean(dim=2)

        # channel excitation
        fc_out_1 = self.relu(self.fc1(squeeze_tensor))
        fc_out_2 = self.sigmoid(self.fc2(fc_out_1))

        a, b = squeeze_tensor.size()
        output_tensor = torch.mul(input_tensor, fc_out_2.view(a, b, 1, 1))
        return output_tensor


class SpatialSELayer(nn.Module):
    """
    Re-implementation of SE block -- squeezing spatially and exciting channel-wise described in:
        *Roy et al., Concurrent Spatial and Channel Squeeze & Excitation in Fully Convolutional Networks, MICCAI 2018*
    """

    def __init__(self, num_channels):
        """
        :param num_channels: No of input channels
        """
        super(SpatialSELayer, self).__init__()
        self.conv = nn.Conv2d(num_channels, 1, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_tensor, weights=None):
        """
        :param weights: weights for few shot learning
        :param input_tensor: X, shape = (batch_size, num_channels, H, W)
        :return: output_tensor
        """
        # spatial squeeze
        batch_size, channel, a, b = input_tensor.size()

        if weights is not None:
            weights = torch.mean(weights, dim=0)
            weights = weights.view(1, channel, 1, 1)
            out = F.conv2d(input_tensor, weights)
        else:
            out = self.conv(input_tensor)
        squeeze_tensor = self.sigmoid(out)

        # spatial excitation
        # print(input_tensor.size(), squeeze_tensor.size())
        squeeze_tensor = squeeze_tensor.view(batch_size, 1, a, b)
        output_tensor = torch.mul(input_tensor, squeeze_tensor)
        #output_tensor = torch.mul(input_tensor, squeeze_tensor)
        return output_tensor


class ChannelSpatialSELayer(nn.Module):
    """
    Re-implementation of concurrent spatial and channel squeeze & excitation:
        *Roy et al., Concurrent Spatial and Channel Squeeze & Excitation in Fully Convolutional Networks, MICCAI 2018, arXiv:1803.02579*
    """

    def __init__(self, num_channels, reduction_ratio=2):
        """
        :param num_channels: No of input channels
        :param reduction_ratio: By how much should the num_channels should be reduced
        """
        super(ChannelSpatialSELayer, self).__init__()
        self.cSE = ChannelSELayer(num_channels, reduction_ratio).cuda(GPU)
        self.sSE = SpatialSELayer(num_channels).cuda(GPU)

    def forward(self, input_tensor):
        """
        :param input_tensor: X, shape = (batch_size, num_channels, H, W)
        :return: output_tensor
        """
        output_tensor = torch.max(self.cSE(input_tensor), self.sSE(input_tensor))
        return output_tensor

# %%
import torch.nn as nn
from efficientnet_pytorch import EfficientNet, model
from efficientnet_pytorch.utils import url_map, url_map_advprop, get_model_params



class EfficientNetEncoder(EfficientNet, EncoderMixin):
    def __init__(self, stage_idxs, out_channels, model_name, depth=5):

        blocks_args, global_params = get_model_params(model_name, override_params=None)
        super().__init__(blocks_args, global_params)

        self._stage_idxs = stage_idxs
        self._out_channels = out_channels
        self._depth = depth
        self._in_channels = 3
        #self.scse = ChannelSpatialSELayer(self._in_channels)
       

        del self._fc

    def get_stages(self):
        return [
            nn.Identity(),
            nn.Sequential(self._conv_stem, self._bn0, self._swish),
            self._blocks[:self._stage_idxs[0]],
            self._blocks[self._stage_idxs[0]:self._stage_idxs[1]],
            self._blocks[self._stage_idxs[1]:self._stage_idxs[2]],
            self._blocks[self._stage_idxs[2]:],
        ]

    def forward(self, x):
        stages = self.get_stages()
        #print(stages)

        block_number = 0.
        drop_connect_rate = self._global_params.drop_connect_rate
        #print(drop_connect_rate)

        features = []
        for i in range(self._depth + 1):

            # Identity and Sequential stages
            if i < 2:
                x = stages[i](x)

            # Block stages need drop_connect rate
            else:
                for module in stages[i]:
                    drop_connect = drop_connect_rate * block_number / len(self._blocks)
                    block_number += 1.
                    x = module(x, drop_connect)

            features.append(x)
            in_ch = x.shape[1]
            #print(in_ch)
            scse = ChannelSpatialSELayer(in_ch)
            x = scse(x)
            #print(x.shape)
            
          
        return x,features

def _get_pretrained_settings(encoder):
    pretrained_settings = {
        "imagenet": {
            "mean": [0.485, 0.456, 0.406],
            "std": [0.229, 0.224, 0.225],
            "url": url_map[encoder],
            "input_space": "RGB",
            "input_range": [0, 1],
        },
    }
    return pretrained_settings

efficient_net_encoders = {
    "efficientnet-b1": {
        "encoder": EfficientNetEncoder,
        "pretrained_settings": _get_pretrained_settings("efficientnet-b1"),
        "params": {
            "out_channels": (3, 32, 24, 40, 112, 320),
            "stage_idxs": (5, 8, 16, 23),
            "model_name": "efficientnet-b1",
        },
    },
}

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F



try:
    from inplace_abn import InPlaceABN
except ImportError:
    InPlaceABN = None

class Conv2dReLU(nn.Sequential):
    def __init__(
            self,
            in_channels,
            out_channels,
            kernel_size,
            padding=0,
            stride=1,
            use_batchnorm=True,
    ):

        if use_batchnorm == "inplace" and InPlaceABN is None:
            raise RuntimeError(
                "In order to use `use_batchnorm='inplace'` inplace_abn package must be installed. "
                + "To install see: https://github.com/mapillary/inplace_abn"
            )

        conv = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size,
            stride=stride,
            padding=padding,
            bias=not (use_batchnorm),
        )
        relu = nn.ReLU(inplace=True)

        if use_batchnorm == "inplace":
            bn = InPlaceABN(out_channels, activation="leaky_relu", activation_param=0.0)
            relu = nn.Identity()

        elif use_batchnorm and use_batchnorm != "inplace":
            bn = nn.BatchNorm2d(out_channels)

        else:
            bn = nn.Identity()

        super(Conv2dReLU, self).__init__(conv, bn, relu)


class Conv2dReLU(nn.Sequential):
    def __init__(
            self,
            in_channels,
            out_channels,
            kernel_size,
            padding=0,
            stride=1,
            use_batchnorm=True,
    ):


        conv = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size,
            stride=stride,
            padding=padding,
            bias=not (use_batchnorm),
        )
        relu = nn.ReLU(inplace=True)

        if use_batchnorm and use_batchnorm != "inplace":
            bn = nn.BatchNorm2d(out_channels)

        else:
            bn = nn.Identity()

        super(Conv2dReLU, self).__init__(conv, bn, relu)



class DecoderBlock(nn.Module):
    def __init__(
            self,
            in_channels,
            skip_channels,
            out_channels,
            use_batchnorm=True,
            attention_type='scse',

    ):
        super().__init__()


        self.conv1 = Conv2dReLU(
            in_channels + skip_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )
        self.attention1 = ChannelSpatialSELayer(num_channels=in_channels + skip_channels)
  
        self.conv2 = Conv2dReLU(
            out_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )

        self.attention2 = ChannelSpatialSELayer(num_channels=out_channels)


    def forward(self, x, skip=None):

        x = F.interpolate(x, scale_factor=2, mode="nearest")
       
        
        if skip is not None:
           
            x = torch.cat([x, skip], dim=1)
            
            
            x = self.attention1(x)
       
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.attention2(x)
        
        return x

class UnetDecoder(nn.Module):
    def __init__( self):
        super().__init__()

       

        in_channels = [640, 256, 128, 64, 32]
        skip_channels = [112, 40, 24, 32, 0]
        out_channels = [256, 128, 64, 32, 16]


      
        blocks = [
            DecoderBlock(in_ch, skip_ch, out_ch)
            for in_ch, skip_ch, out_ch in zip(in_channels, skip_channels, out_channels)
        ]
        self.blocks = nn.ModuleList(blocks)

    def forward(self,x,features):

       
        features = features[1:]                 # remove first skip with same spatial resolution, i.e, channel feature 1280
       
        features = features[::-1]               # reverse channels to start from head of encoder  features = [640,224,80,48,64]
     

        
        skips = features[1:]                    ## skips = [224,80,48,64]


       

        
        for i, decoder_block in enumerate(self.blocks):
            skip = skips[i] if i < len(skips) else None
            x = decoder_block(x, skip)
           

        return x

# %%
model = UnetDecoder()
print(model)
# Out:
# UnetDecoder(
#   (blocks): ModuleList(
#     (0): DecoderBlock(
#       (conv1): Conv2dReLU(
#         (0): Conv2d(752, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention1): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=752, out_features=376, bias=True)
#           (fc2): Linear(in_features=376, out_features=752, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(752, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (conv2): Conv2dReLU(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=256, out_features=128, bias=True)
#           (fc2): Linear(in_features=128, out_features=256, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): DecoderBlock(
#       (conv1): Conv2dReLU(
#         (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention1): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=296, out_features=148, bias=True)
#           (fc2): Linear(in_features=148, out_features=296, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(296, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (conv2): Conv2dReLU(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=128, out_features=64, bias=True)
#           (fc2): Linear(in_features=64, out_features=128, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (2): DecoderBlock(
#       (conv1): Conv2dReLU(
#         (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention1): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=152, out_features=76, bias=True)
#           (fc2): Linear(in_features=76, out_features=152, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(152, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (conv2): Conv2dReLU(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=64, out_features=32, bias=True)
#           (fc2): Linear(in_features=32, out_features=64, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (3): DecoderBlock(
#       (conv1): Conv2dReLU(
#         (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention1): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=96, out_features=48, bias=True)
#           (fc2): Linear(in_features=48, out_features=96, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(96, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (conv2): Conv2dReLU(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=32, out_features=16, bias=True)
#           (fc2): Linear(in_features=16, out_features=32, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (4): DecoderBlock(
#       (conv1): Conv2dReLU(
#         (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention1): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=32, out_features=16, bias=True)
#           (fc2): Linear(in_features=16, out_features=32, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (conv2): Conv2dReLU(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (attention2): ChannelSpatialSELayer(
#         (cSE): ChannelSELayer(
#           (fc1): Linear(in_features=16, out_features=8, bias=True)
#           (fc2): Linear(in_features=8, out_features=16, bias=True)
#           (relu): ReLU()
#           (sigmoid): Sigmoid()
#         )
#         (sSE): SpatialSELayer(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
# )

# %%
import torch.utils.model_zoo as model_zoo

encoders = {}
encoders.update(efficient_net_encoders)

def get_encoder(name, in_channels=3, depth=5, weights=None):

    if weights == None:
      print("Training from Scratch !!")

    try:
        Encoder = encoders[name]["encoder"]
       
    except KeyError:
        raise KeyError("Wrong encoder name `{}`, supported encoders: {}".format(name, list(encoders.keys())))



    params = encoders[name]["params"]
   
    
    params.update(depth=depth)
    
   
    encoder = Encoder(**params)

    if weights is not None:
        try:
            settings = encoders[name]["pretrained_settings"][weights]
        except KeyError:
            raise KeyError("Wrong pretrained weights `{}` for encoder `{}`. Available options are: {}".format(
                weights, name, list(encoders[name]["pretrained_settings"].keys()),
            ))
        encoder.load_state_dict(model_zoo.load_url(settings["url"]))

    encoder.set_in_channels(in_channels)
    

    return encoder

# %%
class SegmentationHead(nn.Sequential):

    def __init__(self, in_channels, out_channels, kernel_size=3, activation='sigmoid', upsampling=1):
        conv2d = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=kernel_size // 2)
        upsampling = nn.UpsamplingBilinear2d(scale_factor=upsampling) if upsampling > 1 else nn.Identity()
        activation = nn.Sigmoid()
        super().__init__(conv2d, upsampling, activation)

# %%
def initialize_decoder(module):
    for m in module.modules():

        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_uniform_(m.weight, mode="fan_in", nonlinearity="relu")
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

        elif isinstance(m, nn.BatchNorm2d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

        elif isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


def initialize_head(module):
    for m in module.modules():
        if isinstance(m, (nn.Linear, nn.Conv2d)):
            nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

# %%
classes_name = os.listdir('FewShot/fss1000/')
classes = list(range(0,len(classes_name)))

chosen_classes = random.sample(classes, CLASS_NUM)

def get_oneshot_batch():
  
        # print ('class %s is chosen' % i)
      classes_name = os.listdir('FewShot/fss1000/')
      classes = list(range(0,len(classes_name)))
      

      chosen_classes = random.sample(classes, CLASS_NUM)
      #print(chosen_classes)
      support_images = np.zeros((CLASS_NUM*SAMPLE_NUM_PER_CLASS,3,224,224), dtype=np.float32)
      support_labels = np.zeros((CLASS_NUM*SAMPLE_NUM_PER_CLASS,CLASS_NUM,224,224), dtype=np.float32)
      query_images = np.zeros((CLASS_NUM*BATCH_NUM_PER_CLASS,3,224,224), dtype=np.float32)
      query_labels = np.zeros((CLASS_NUM*BATCH_NUM_PER_CLASS,CLASS_NUM,224,224), dtype=np.float32)
      zeros = np.zeros((CLASS_NUM*BATCH_NUM_PER_CLASS,1,224,224), dtype=np.float32)
      class_cnt = 0

      for i in chosen_classes:
        # print ('class %s is chosen' % i)
        imgnames = os.listdir('FewShot/fss1000/%s/label' % classes_name[i])
        indexs = list(range(0,len(imgnames)))
        #print(len(indexs))
        chosen_index = random.sample(indexs, SAMPLE_NUM_PER_CLASS + BATCH_NUM_PER_CLASS)
        #print(len(chosen_index))
        j = 0
        for k in chosen_index:
            # process image
            image = cv2.imread('FewShot/fss1000/%s/image/%s' % (classes_name[i], imgnames[k].replace('.png', '.jpg')))
            image = cv2.resize(image,(224,224))
            if image is None:
                print ('FewShot/fss1000/%s/image/%s' % (classes_name[i], imgnames[k].replace('.png', '.jpg')))
                
            image = image[:,:,::-1] # bgr to rgb
            image = image / 255.0
            image = np.transpose(image, (2,0,1))
            # labels
            label = cv2.imread('FewShot/fss1000/%s/label/%s' % (classes_name[i], imgnames[k]))[:,:,0]
            label = cv2.resize(label,(224,224))
            label = label/255.0
            
            if j < SAMPLE_NUM_PER_CLASS:
                support_images[j] = image
                support_labels[j][0] = label
            else:
                query_images[j-SAMPLE_NUM_PER_CLASS] = image
                query_labels[j-SAMPLE_NUM_PER_CLASS][class_cnt] = label
            j += 1

        class_cnt += 1
      support_images_tensor = torch.from_numpy(support_images)
      support_labels_tensor = torch.from_numpy(support_labels)
      support_images_tensor = torch.cat((support_images_tensor,support_labels_tensor), dim=1)

      zeros_tensor = torch.from_numpy(zeros)
      query_images_tensor = torch.from_numpy(query_images)
      query_images_tensor = torch.cat((query_images_tensor,zeros_tensor), dim=1)
      query_labels_tensor = torch.from_numpy(query_labels)

      return support_images_tensor, support_labels_tensor, query_images_tensor, query_labels_tensor, chosen_classes

# %%
samples, sample_labels, batches, batch_labels, chosen_classes = get_oneshot_batch()
print(samples.shape)
print(sample_labels.shape)
print(batches.shape)
print(batch_labels.shape)
print(chosen_classes)
# Out:
# torch.Size([5, 4, 224, 224])
# torch.Size([5, 1, 224, 224])
# torch.Size([5, 4, 224, 224])
# torch.Size([5, 1, 224, 224])
# [527]

# %%
print(torch.max(batch_labels))
# Out:
# tensor(1.)

# %%
def get_pascal_labels():
    """Load the mapping that associates pascal classes with label colors

    Returns:
        np.ndarray with dimensions (21, 3)
    """
    return np.asarray([[0,0,0], [128,0,0], [0,128,0], [128,128,0],
                      [0,0,128], [128,0,128], [0,128,128], [128,128,128],
                      [64,0,0], [192,0,0], [64,128,0], [192,128,0],
                      [64,0,128], [192,0,128], [64,128,128], [192,128,128],
                      [0, 64,0], [128, 64, 0], [0,192,0], [128,192,0],
                      [0,64,128]])


def encode_segmap(mask):
    """Encode segmentation label images as pascal classes

    Args:
        mask (np.ndarray): raw segmentation label image of dimension
          (M, N, 3), in which the Pascal classes are encoded as colours.

    Returns:
        (np.ndarray): class map with dimensions (M,N), where the value at
        a given location is the integer denoting the class index.
    """
    mask = mask.astype(int)
    label_mask = np.zeros((mask.shape[0], mask.shape[1]), dtype=np.int16)
    for ii, label in enumerate(get_pascal_labels()):
        label_mask[np.where(np.all(mask == label, axis=-1))[:2]] = ii
    label_mask = label_mask.astype(int)
    return label_mask


def decode_segmap(label_mask, plot=False):
    """Decode segmentation class labels into a color image

    Args:
        label_mask (np.ndarray): an (M,N) array of integer values denoting
          the class label at each spatial location.
        plot (bool, optional): whether to show the resulting color image
          in a figure.

    Returns:
        (np.ndarray, optional): the resulting decoded color image.
    """
    label_colours = get_pascal_labels()
    r = label_mask.copy()
    g = label_mask.copy()
    b = label_mask.copy()
    for ll in range(0, 21):
        r[label_mask == ll] = label_colours[ll, 0]
        g[label_mask == ll] = label_colours[ll, 1]
        b[label_mask == ll] = label_colours[ll, 2]
    rgb = np.zeros((label_mask.shape[0], label_mask.shape[1], 3))
    rgb[:, :, 0] = r #/ 255.0
    rgb[:, :, 1] = g #/ 255.0
    rgb[:, :, 2] = b #/ 255.0
    if plot:
        plt.imshow(rgb)
        plt.show()
    else:
        return rgb

# %%
def evaluate_predictions(predictions, labels):
    pred = predictions.data.cpu().numpy()
    
    pred[pred <= 0.5] = 0
    pred[pred > 0.5] = 1
    testlabel = labels.numpy()[0][0].astype(bool)
    pred = pred.astype(bool)
    # Compute IOU
    overlap = testlabel * pred
    union = testlabel + pred
    iou = overlap.sum() / float(union.sum())
   
    return iou

# %%
def main():

    
    print("Neural Networks")

    encoder = get_encoder('efficientnet-b1',in_channels=4,weights=None)
    decoder = UnetDecoder()
    head = SegmentationHead(in_channels=16,out_channels=1)


    initialize_decoder(decoder)
    initialize_head(head) 

    encoder.cuda(GPU)
    decoder.cuda(GPU)
    head.cuda(GPU) 



    encoder_optim = torch.optim.Adam(encoder.parameters(),lr=LEARNING_RATE)
    encoder_scheduler = StepLR(encoder_optim,step_size=EPISODE//10,gamma=0.5)

    decoder_optim = torch.optim.Adam(decoder.parameters(),lr=LEARNING_RATE)
    decoder_scheduler = StepLR(decoder_optim,step_size=EPISODE//10,gamma=0.5)

    head_optim = torch.optim.Adam(head.parameters(),lr=LEARNING_RATE)
    head_scheduler = StepLR(head_optim,step_size=EPISODE//10,gamma=0.5)


    if (args.finetune):

      if os.path.exists(ENCODER_MODEL):

          checkpoint1 = torch.load(ENCODER_MODEL)
          encoder.load_state_dict(checkpoint1['encoder_state_dict'])
          encoder_optim.load_state_dict(checkpoint1['optimizer_state_dict'])
          encoder_scheduler.load_state_dict(checkpoint1['scheduler_state_dict'])

       
          print("load encoder success")

      else:
          print('Can not load encoder: %s' % ENCODER_MODEL)
          print('starting from scratch')
          
      if os.path.exists(DECODER_MODEL):

          checkpoint2 = torch.load(DECODER_MODEL)
          decoder.load_state_dict(checkpoint2['decoder_state_dict'])
          decoder_optim.load_state_dict(checkpoint2['optimizer_state_dict'])
          decoder_scheduler.load_state_dict(checkpoint2['scheduler_state_dict'])

          print("load decoder success")

      else:
          print('Can not load decoder: %s' % DECODER_MODEL)
          print('starting from scratch')

      if os.path.exists(HEAD_MODEL):

          checkpoint3 = torch.load(HEAD_MODEL)
          head.load_state_dict(checkpoint3['head_state_dict'])
          head_optim.load_state_dict(checkpoint3['optimizer_state_dict'])
          head_scheduler.load_state_dict(checkpoint3['scheduler_state_dict'])

          print("load head success")

      else:
        print('Can not load head: %s' % HEAD_MODEL)
        print('starting from scratch')
    




    print("Training...")

    last_accuracy = 0.0
     
     
    for episode in range(args.start_episode, EPISODE):
        encoder_scheduler.step(episode)
        decoder_scheduler.step(episode)
        head_scheduler.step(episode)

        samples, sample_labels, batches, batch_labels, chosen_classes = get_oneshot_batch()


        # calculate features
        sample_features, _ = encoder(Variable(samples).cuda(GPU))  ## 5*320*7*7
        sample_features = sample_features.view(CLASS_NUM,SAMPLE_NUM_PER_CLASS,320,7,7)  ## 1*5*320*7*7
        sample_features = torch.sum(sample_features,1).squeeze(1) # 1*320*7*7
        batch_features, ft_list = encoder(Variable(batches).cuda(GPU))  ## 5*320*7*7

        # calculate relations
        sample_features_ext = sample_features.unsqueeze(0).repeat(BATCH_NUM_PER_CLASS*CLASS_NUM,1,1,1,1) ## 5*320*7*7
        batch_features_ext = batch_features.unsqueeze(0).repeat(CLASS_NUM,1,1,1,1)
        batch_features_ext = torch.transpose(batch_features_ext,0,1) ## 5*1*320*7*7

        relation_pairs = torch.cat((sample_features_ext,batch_features_ext),2).view(-1,640,7,7) ## 5*640*7*7
        out = decoder(relation_pairs,ft_list)
        output = head(out).view(-1,CLASS_NUM,224,224)

        bce = nn.BCELoss().cuda(GPU)
        loss = bce(output,Variable(batch_labels).cuda(GPU))


        # training

        encoder.zero_grad()
        decoder.zero_grad()
        head.zero_grad()

        loss.backward()


        torch.nn.utils.clip_grad_norm(encoder.parameters(),0.5)
        torch.nn.utils.clip_grad_norm(decoder.parameters(),0.5)
        torch.nn.utils.clip_grad_norm(head.parameters(),0.5)

        encoder_optim.step()
        decoder_optim.step()
        head_optim.step()

        if (episode+1)%10 == 0:
                
                print("episode: ",episode+1," loss: ",loss.cpu().data.numpy())
                

        if not os.path.exists(args.TrainResultPath):
            os.makedirs(args.TrainResultPath)
        if not os.path.exists(args.ModelSavePath):
            os.makedirs(args.ModelSavePath)

        # training result visualization
        if (episode+1)%args.ResultSaveFreq == 0:
          support_output = np.zeros((224*2, 224*SAMPLE_NUM_PER_CLASS, 3), dtype=np.uint8)
          query_output = np.zeros((224*3, 224*DISPLAY_QUERY, 3), dtype=np.uint8)
          chosen_query = random.sample(list(range(0,BATCH_NUM_PER_CLASS)), DISPLAY_QUERY)

          for i in range(CLASS_NUM):
              for j in range(SAMPLE_NUM_PER_CLASS):
                  supp_img = (np.transpose(samples.numpy()[j],(1,2,0))*255).astype(np.uint8)[:,:,:3][:,:,::-1]
                  support_output[0:224,j*224:(j+1)*224,:] = supp_img
                  supp_label = sample_labels.numpy()[j][0]
                  supp_label[supp_label!=0] = chosen_classes[i]
                  supp_label = decode_segmap(supp_label)
                  support_output[224:224*2, j*224:(j+1)*224,:] = supp_label

              for cnt, x in enumerate(chosen_query):
                  query_img = (np.transpose(batches.numpy()[x],(1,2,0))*255).astype(np.uint8)[:,:,:3][:,:,::-1]
                  query_output[0:224,cnt*224:(cnt+1)*224,:] = query_img
                  query_label = batch_labels.numpy()[x][0] #only apply to one-way setting
                  query_label[query_label!=0] = chosen_classes[i]
                  query_label = decode_segmap(query_label)
                  query_output[224:224*2, cnt*224:(cnt+1)*224,:] = query_label

                  query_pred = output.detach().cpu().numpy()[x][0]
                  query_pred = (query_pred*255).astype(np.uint8)
                  result = np.zeros((224,224,3), dtype=np.uint8)
                  result[:,:,0] = query_pred
                  result[:,:,1] = query_pred
                  result[:,:,2] = query_pred
                  query_output[224*2:224*3, cnt*224:(cnt+1)*224,:] = result
          extra = query_output.copy()
          for i in range(CLASS_NUM):
              for cnt, x in enumerate(chosen_query):
                  extra_label = batch_labels.numpy()[x][0]
                  extra_label[extra_label!=0] = 255
                  result1 = np.zeros((224,224,3), dtype=np.uint8)
                  result1[:,:,0] = extra_label
                  result1[:,:,1] = extra_label
                  result1[:,:,2] = extra_label
                  extra[224*2:224*3, cnt*224:(cnt+1)*224,:] = result1
          cv2.imwrite('%s/%s_query.png' % (args.TrainResultPath, episode), query_output)
          cv2.imwrite('%s/%s_show.png' % (args.TrainResultPath,episode), extra)
          cv2.imwrite('%s/%s_support.png' % (args.TrainResultPath, episode), support_output)
       


        if (episode+1) % args.ModelSaveFreq == 0:

            torch.save({'encoder_state_dict':encoder.state_dict(),
                        'optimizer_state_dict':encoder_optim.state_dict(),
                        'scheduler_state_dict':encoder_scheduler.state_dict()},str("./%s/efficientnet_encoder_" % args.ModelSavePath + str(episode) + '_' + str(CLASS_NUM) +"_way_" + str(SAMPLE_NUM_PER_CLASS) +"shot.pkl"))
            
            
            
            torch.save({'decoder_state_dict':decoder.state_dict(),
                        'optimizer_state_dict':decoder_optim.state_dict(),
                        'scheduler_state_dict':decoder_scheduler.state_dict()},str("./%s/decoder_network_" % args.ModelSavePath + str(episode) + '_' + str(CLASS_NUM) +"_way_" + str(SAMPLE_NUM_PER_CLASS) +"shot.pkl"))
            
            
            torch.save({'head_state_dict':head.state_dict(),
                        'optimizer_state_dict':head_optim.state_dict(),
                        'scheduler_state_dict':head_scheduler.state_dict()},str("./%s/segmentation_network_" % args.ModelSavePath + str(episode) + '_' + str(CLASS_NUM) +"_way_" + str(SAMPLE_NUM_PER_CLASS) +"shot.pkl"))
            
            print("save networks for episode:",episode)

# %%
if __name__ == '__main__':
    main()
# Out:
# Neural Networks
# Training from Scratch !!
# Can not load encoder:
# starting from scratch
# Can not load decoder:
# starting from scratch
# Can not load head:
# starting from scratch
# Training...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:154: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# __main__:117: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# __main__:118: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# __main__:119: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# episode:  10  loss:  0.5546954
# episode:  20  loss:  0.54514855
# episode:  30  loss:  0.4579239
# episode:  40  loss:  0.28553572
# episode:  50  loss:  0.4579079
# episode:  60  loss:  0.44464803
# episode:  70  loss:  0.25240195
# episode:  80  loss:  0.25609633
# episode:  90  loss:  0.26752493
# episode:  100  loss:  0.3281019
# episode:  110  loss:  0.33714977
# episode:  120  loss:  0.37931293
# episode:  130  loss:  0.5089515
# episode:  140  loss:  0.33755985
# episode:  150  loss:  0.37731352
# episode:  160  loss:  0.33487046
# episode:  170  loss:  0.26169822
# episode:  180  loss:  0.22895706
# episode:  190  loss:  0.4740355
# episode:  200  loss:  0.3560133
# episode:  210  loss:  0.32542008
# episode:  220  loss:  0.6501829
# episode:  230  loss:  0.4955378
# episode:  240  loss:  0.5525158
# episode:  250  loss:  0.36834988
# episode:  260  loss:  0.36341396
# episode:  270  loss:  0.30193266
# episode:  280  loss:  0.39161363
# episode:  290  loss:  0.64152867
# episode:  300  loss:  0.40858153
# episode:  310  loss:  0.23647046
# episode:  320  loss:  0.39022222
# episode:  330  loss:  0.65843976
# episode:  340  loss:  0.2171878
# episode:  350  loss:  0.39828506
# episode:  360  loss:  0.25998113
# episode:  370  loss:  0.38821796
# episode:  380  loss:  0.18992867
# episode:  390  loss:  0.45372984
# episode:  400  loss:  0.32864153
# episode:  410  loss:  0.4478449
# episode:  420  loss:  0.34539512
# episode:  430  loss:  0.30521214
# episode:  440  loss:  0.26266092
# episode:  450  loss:  0.22727633

# %%
# !cp /content/models_newvgg_1shot/efficientnet_encoder_99999_1_way_5shot.pkl /content/drive/MyDrive/CGM
